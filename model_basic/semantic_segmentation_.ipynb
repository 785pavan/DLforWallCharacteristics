# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import random
import re
from PIL import Image
import glob


import numpy as np
import matplotlib.pyplot as plt
from pylab import *
import os
import sys
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import *


#from tensorflow.keras.engine import Layer
from tensorflow.keras.applications.vgg16 import *
from tensorflow.keras.models import *
#from tensorflow.keras.applications.imagenet_utils import _obtain_input_shape
import tensorflow.keras.backend as K
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Convolution2D, ZeroPadding2D, MaxPooling2D, Cropping2D, Conv2D
from tensorflow.keras.layers import Input, Add, Dropout, Permute, add
from tensorflow.compat.v1.layers import conv2d_transpose
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.python.keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
print(tf.__version__)
# Out:
# 2.3.0

# %%
x = tf.random.uniform([3, 3])

print("Is there a GPU available: "),
print(tf.config.list_physical_devices('GPU'))

print("Is the Tensor on GPU #0:  "),
print(x.device.endswith('GPU:0'))

print("Device name: {}".format((x.device)))
# Out:
# Is there a GPU available:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Is the Tensor on GPU #0:
# True
# Device name: /job:localhost/replica:0/task:0/device:GPU:0

# %%
print(tf.executing_eagerly())
tf.compat.v1.enable_eager_execution()
tf.config.experimental_run_functions_eagerly(True) 
#tf.config.run_functions_eagerly(True)
# Out:
# True

# %%
def _read_to_tensor(fname, output_height=256, output_width=256, normalize_data=False):
    '''Function to read images from given image file path, and provide resized images as tensors
        Inputs: 
            fname - image file path
            output_height - required output image height
            output_width - required output image width
            normalize_data - if True, normalize data to be centered around 0 (mean 0, range 0 to 1)
        Output: Processed image tensors
    '''
    
    # Read the image as a tensor
    img_strings = tf.io.read_file(fname)
    imgs_decoded = tf.image.decode_jpeg(img_strings)
    
    # Resize the image
    output = tf.image.resize(imgs_decoded, [output_height, output_width])
    
    # Normalize if required
    if normalize_data:
        output = (output - 128) / 128
    return output

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
img_dir = '/content/drive/My Drive/segmentation/image/'
masks_dir='/content/drive/My Drive/segmentation/masks/'

# Required image dimensions
output_height = 256
output_width = 256

# %%
# os.remove('/content/drive/My Drive/segmentation/masks/S_385 (26)_0875 (1).png')
# os.remove('/content/drive/My Drive/segmentation/masks/S_385 (26)_0876 (1).png')
# os.remove('/content/drive/My Drive/segmentation/masks/S_385 (26)_0877 (1).png')
# os.remove('/content/drive/My Drive/segmentation/masks/S_385 (26)_0878 (1).png')
# os.remove('/content/drive/My Drive/segmentation/masks/S_385 (26)_0879 (1).png')
# os.remove('/content/drive/My Drive/segmentation/masks/S_385 (26)_0880 (1).png')
# os.remove('/content/drive/My Drive/segmentation/masks/S_385 (26)_0881 (1).png')
# os.remove('/content/drive/My Drive/segmentation/masks/S_385 (26)_0882 (1).png')
# os.remove('/content/drive/My Drive/segmentation/masks/S_385 (26)_0885 (1).png')
# os.remove('/content/drive/My Drive/segmentation/masks/S_385 (26)_0886 (1).png')

# %%
def read_images(img_dir,masks_dir):
    '''Function to get all image directories, read images and masks in separate tensors
        Inputs: 
            img_dir - image directory
            masks_dir- masks directory
        Outputs 
            image_tensors, masks_tensors, image files list, mask files list
    '''
    print('length of image dir',len(img_dir))
    print('length of masks dir',len(masks_dir))


    # Get the file names list from provided directory
    image_list = [f for f in os.listdir(img_dir) if os.path.isfile(os.path.join(img_dir, f))]
    print('length of image un_sorted list',len(image_list))
    image_list=sorted(image_list)
    masks_list = [f for f in os.listdir(masks_dir) if os.path.isfile(os.path.join(masks_dir, f))]
    print('length of masks un_sorted list',len(masks_list))
    masks_list=sorted(masks_list)

    # Separate image and mask files lists, exclude unnecessary files
    #image_list = [file for file in image_list if ('.png' in file)] #and ('txt' not in file)]
    #masks_list = [file for file in masks_list if ('.png' in file)] #and ('txt' not in file)]
    
    print('{} image files found in the provided directory.'.format(len(image_list)))
    print('{} mask files found in the provided directory.'.format(len(masks_list)))
    
    # Create file paths from file names
    image_paths = [os.path.join(img_dir, fname) for fname in image_list]
    masks_paths = [os.path.join(masks_dir, fname) for fname in masks_list]
    
    # Create dataset of tensors
    image_data = tf.data.Dataset.from_tensor_slices(image_paths)
    masks_data = tf.data.Dataset.from_tensor_slices(masks_paths)
    
    # Read images into the tensor dataset
    image_tensors = image_data.map(_read_to_tensor)
    masks_tensors = masks_data.map(_read_to_tensor)
    
    print('Completed importing {} images from the provided directory.'.format(len(image_list)))
    print('Completed importing {} mask images from the provided directory.'.format(len(masks_list)))

    print(image_list)
    print(masks_list)
    
    return image_tensors, masks_tensors, image_list, masks_list

image_tensors, masks_tensors, image_list, masks_list = read_images(img_dir,masks_dir)
# Out:
# length of image dir 43
# length of masks dir 43
# length of image un_sorted list 6095
# length of masks un_sorted list 6095
# 6095 image files found in the provided directory.
# 6095 mask files found in the provided directory.
# Completed importing 6095 images from the provided directory.
# Completed importing 6095 mask images from the provided directory.
# ['S_385 (19)_0024.png', 'S_385 (19)_0043.png', 'S_385 (19)_0044.png', 'S_385 (19)_0045.png', 'S_385 (19)_0046.png', 'S_385 (19)_0048.png', 'S_385 (19)_0066.png', 'S_385 (19)_0067.png', 'S_385 (19)_0070.png', 'S_385 (19)_0072.png', 'S_385 (19)_0088.png', 'S_385 (19)_0089.png', 'S_385 (19)_0090.png', 'S_385 (19)_0093.png', 'S_385 (19)_0094.png', 'S_385 (19)_0096.png', 'S_385 (19)_0111.png', 'S_385 (19)_0112.png', 'S_385 (19)_0113.png', 'S_385 (19)_0114.png', 'S_385 (19)_0117.png', 'S_385 (19)_0118.png', 'S_385 (19)_0120.png', 'S_385 (19)_0134.png', 'S_385 (19)_0135.png', 'S_385 (19)_0136.png', 'S_385 (19)_0137.png', 'S_385 (19)_0141.png', 'S_385 (19)_0144.png', 'S_385 (19)_0157.png', 'S_385 (19)_0158.png', 'S_385 (19)_0159.png', 'S_385 (19)_0160.png', 'S_385 (19)_0165.png', 'S_385 (19)_0168.png', 'S_385 (19)_0180.png', 'S_385 (19)_0181.png', 'S_385 (19)_0182.png', 'S_385 (19)_0183.png', 'S_385 (19)_0184.png', 'S_385 (19)_0188.png', 'S_385 (19)_0189.png', 'S_385 (19)_0192.png', 'S_385 (19)_0203.png', 'S_385 (19)_0204.png', 'S_385 (19)_0205.png', 'S_385 (19)_0212.png', 'S_385 (19)_0213.png', 'S_385 (19)_0216.png', 'S_385 (19)_0226.png', 'S_385 (19)_0227.png', 'S_385 (19)_0228.png', 'S_385 (19)_0229.png', 'S_385 (19)_0235.png', 'S_385 (19)_0236.png', 'S_385 (19)_0237.png', 'S_385 (19)_0240.png', 'S_385 (19)_0249.png', 'S_385 (19)_0250.png', 'S_385 (19)_0251.png', 'S_385 (19)_0252.png', 'S_385 (19)_0253.png', 'S_385 (19)_0254.png', 'S_385 (19)_0259.png', 'S_385 (19)_0260.png', 'S_385 (19)_0261.png', 'S_385 (19)_0264.png', 'S_385 (19)_0272.png', 'S_385 (19)_0273.png', 'S_385 (19)_0274.png', 'S_385 (19)_0275.png', 'S_385 (19)_0276.png', 'S_385 (19)_0277.png', 'S_385 (19)_0278.png', 'S_385 (19)_0279.png', 'S_385 (19)_0283.png', 'S_385 (19)_0284.png', 'S_385 (19)_0288.png', 'S_385 (19)_0296.png', 'S_385 (19)_0297.png', 'S_385 (19)_0298.png', 'S_385 (19)_0299.png', 'S_385 (19)_0300.png', 'S_385 (19)_0301.png', 'S_385 (19)_0302.png', 'S_385 (19)_0303.png', 'S_385 (19)_0307.png', 'S_385 (19)_0308.png', 'S_385 (19)_0312.png', 'S_385 (19)_0319.png', 'S_385 (19)_0320.png', 'S_385 (19)_0321.png', 'S_385 (19)_0322.png', 'S_385 (19)_0323.png', 'S_385 (19)_0324.png', 'S_385 (19)_0325.png', 'S_385 (19)_0326.png', 'S_385 (19)_0327.png', 'S_385 (19)_0330.png', 'S_385 (19)_0331.png', 'S_385 (19)_0336.png', 'S_385 (19)_0342.png', 'S_385 (19)_0343.png', 'S_385 (19)_0344.png', 'S_385 (19)_0345.png', 'S_385 (19)_0346.png', 'S_385 (19)_0347.png', 'S_385 (19)_0348.png', 'S_385 (19)_0349.png', 'S_385 (19)_0350.png', 'S_385 (19)_0351.png', 'S_385 (19)_0352.png', 'S_385 (19)_0354.png', 'S_385 (19)_0355.png', 'S_385 (19)_0360.png', 'S_385 (19)_0366.png', 'S_385 (19)_0367.png', 'S_385 (19)_0368.png', 'S_385 (19)_0369.png', 'S_385 (19)_0370.png', 'S_385 (19)_0371.png', 'S_385 (19)_0372.png', 'S_385 (19)_0373.png', 'S_385 (19)_0374.png', 'S_385 (19)_0375.png', 'S_385 (19)_0377.png', 'S_385 (19)_0378.png', 'S_385 (19)_0379.png', 'S_385 (19)_0380.png', 'S_385 (19)_0384.png', 'S_385 (19)_0390.png', 'S_385 (19)_0391.png', 'S_385 (19)_0392.png', 'S_385 (19)_0393.png', 'S_385 (19)_0394.png', 'S_385 (19)_0395.png', 'S_385 (19)_0396.png', 'S_385 (19)_0397.png', 'S_385 (19)_0398.png', 'S_385 (19)_0399.png', 'S_385 (19)_0402.png', 'S_385 (19)_0403.png', 'S_385 (19)_0404.png', 'S_385 (19)_0408.png', 'S_385 (19)_0414.png', 'S_385 (19)_0415.png', 'S_385 (19)_0416.png', 'S_385 (19)_0417.png', 'S_385 (19)_0418.png', 'S_385 (19)_0419.png', 'S_385 (19)_0420.png', 'S_385 (19)_0421.png', 'S_385 (19)_0422.png', 'S_385 (19)_0423.png', 'S_385 (19)_0424.png', 'S_385 (19)_0426.png', 'S_385 (19)_0427.png', 'S_385 (19)_0428.png', 'S_385 (19)_0429.png', 'S_385 (19)_0432.png', 'S_385 (19)_0438.png', 'S_385 (19)_0439.png', 'S_385 (19)_0440.png', 'S_385 (19)_0441.png', 'S_385 (19)_0442.png', 'S_385 (19)_0443.png', 'S_385 (19)_0444.png', 'S_385 (19)_0445.png', 'S_385 (19)_0446.png', 'S_385 (19)_0447.png', 'S_385 (19)_0448.png', 'S_385 (19)_0451.png', 'S_385 (19)_0452.png', 'S_385 (19)_0453.png ...
# ['S_385 (19)_0024.png', 'S_385 (19)_0043.png', 'S_385 (19)_0044.png', 'S_385 (19)_0045.png', 'S_385 (19)_0046.png', 'S_385 (19)_0048.png', 'S_385 (19)_0066.png', 'S_385 (19)_0067.png', 'S_385 (19)_0070.png', 'S_385 (19)_0072.png', 'S_385 (19)_0088.png', 'S_385 (19)_0089.png', 'S_385 (19)_0090.png', 'S_385 (19)_0093.png', 'S_385 (19)_0094.png', 'S_385 (19)_0096.png', 'S_385 (19)_0111.png', 'S_385 (19)_0112.png', 'S_385 (19)_0113.png', 'S_385 (19)_0114.png', 'S_385 (19)_0117.png', 'S_385 (19)_0118.png', 'S_385 (19)_0120.png', 'S_385 (19)_0134.png', 'S_385 (19)_0135.png', 'S_385 (19)_0136.png', 'S_385 (19)_0137.png', 'S_385 (19)_0141.png', 'S_385 (19)_0144.png', 'S_385 (19)_0157.png', 'S_385 (19)_0158.png', 'S_385 (19)_0159.png', 'S_385 (19)_0160.png', 'S_385 (19)_0165.png', 'S_385 (19)_0168.png', 'S_385 (19)_0180.png', 'S_385 (19)_0181.png', 'S_385 (19)_0182.png', 'S_385 (19)_0183.png', 'S_385 (19)_0184.png', 'S_385 (19)_0188.png', 'S_385 (19)_0189.png', 'S_385 (19)_0192.png', 'S_385 (19)_0203.png', 'S_385 (19)_0204.png', 'S_385 (19)_0205.png', 'S_385 (19)_0212.png', 'S_385 (19)_0213.png', 'S_385 (19)_0216.png', 'S_385 (19)_0226.png', 'S_385 (19)_0227.png', 'S_385 (19)_0228.png', 'S_385 (19)_0229.png', 'S_385 (19)_0235.png', 'S_385 (19)_0236.png', 'S_385 (19)_0237.png', 'S_385 (19)_0240.png', 'S_385 (19)_0249.png', 'S_385 (19)_0250.png', 'S_385 (19)_0251.png', 'S_385 (19)_0252.png', 'S_385 (19)_0253.png', 'S_385 (19)_0254.png', 'S_385 (19)_0259.png', 'S_385 (19)_0260.png', 'S_385 (19)_0261.png', 'S_385 (19)_0264.png', 'S_385 (19)_0272.png', 'S_385 (19)_0273.png', 'S_385 (19)_0274.png', 'S_385 (19)_0275.png', 'S_385 (19)_0276.png', 'S_385 (19)_0277.png', 'S_385 (19)_0278.png', 'S_385 (19)_0279.png', 'S_385 (19)_0283.png', 'S_385 (19)_0284.png', 'S_385 (19)_0288.png', 'S_385 (19)_0296.png', 'S_385 (19)_0297.png', 'S_385 (19)_0298.png', 'S_385 (19)_0299.png', 'S_385 (19)_0300.png', 'S_385 (19)_0301.png', 'S_385 (19)_0302.png', 'S_385 (19)_0303.png', 'S_385 (19)_0307.png', 'S_385 (19)_0308.png', 'S_385 (19)_0312.png', 'S_385 (19)_0319.png', 'S_385 (19)_0320.png', 'S_385 (19)_0321.png', 'S_385 (19)_0322.png', 'S_385 (19)_0323.png', 'S_385 (19)_0324.png', 'S_385 (19)_0325.png', 'S_385 (19)_0326.png', 'S_385 (19)_0327.png', 'S_385 (19)_0330.png', 'S_385 (19)_0331.png', 'S_385 (19)_0336.png', 'S_385 (19)_0342.png', 'S_385 (19)_0343.png', 'S_385 (19)_0344.png', 'S_385 (19)_0345.png', 'S_385 (19)_0346.png', 'S_385 (19)_0347.png', 'S_385 (19)_0348.png', 'S_385 (19)_0349.png', 'S_385 (19)_0350.png', 'S_385 (19)_0351.png', 'S_385 (19)_0352.png', 'S_385 (19)_0354.png', 'S_385 (19)_0355.png', 'S_385 (19)_0360.png', 'S_385 (19)_0366.png', 'S_385 (19)_0367.png', 'S_385 (19)_0368.png', 'S_385 (19)_0369.png', 'S_385 (19)_0370.png', 'S_385 (19)_0371.png', 'S_385 (19)_0372.png', 'S_385 (19)_0373.png', 'S_385 (19)_0374.png', 'S_385 (19)_0375.png', 'S_385 (19)_0377.png', 'S_385 (19)_0378.png', 'S_385 (19)_0379.png', 'S_385 (19)_0380.png', 'S_385 (19)_0384.png', 'S_385 (19)_0390.png', 'S_385 (19)_0391.png', 'S_385 (19)_0392.png', 'S_385 (19)_0393.png', 'S_385 (19)_0394.png', 'S_385 (19)_0395.png', 'S_385 (19)_0396.png', 'S_385 (19)_0397.png', 'S_385 (19)_0398.png', 'S_385 (19)_0399.png', 'S_385 (19)_0402.png', 'S_385 (19)_0403.png', 'S_385 (19)_0404.png', 'S_385 (19)_0408.png', 'S_385 (19)_0414.png', 'S_385 (19)_0415.png', 'S_385 (19)_0416.png', 'S_385 (19)_0417.png', 'S_385 (19)_0418.png', 'S_385 (19)_0419.png', 'S_385 (19)_0420.png', 'S_385 (19)_0421.png', 'S_385 (19)_0422.png', 'S_385 (19)_0423.png', 'S_385 (19)_0424.png', 'S_385 (19)_0426.png', 'S_385 (19)_0427.png', 'S_385 (19)_0428.png', 'S_385 (19)_0429.png', 'S_385 (19)_0432.png', 'S_385 (19)_0438.png', 'S_385 (19)_0439.png', 'S_385 (19)_0440.png', 'S_385 (19)_0441.png', 'S_385 (19)_0442.png', 'S_385 (19)_0443.png', 'S_385 (19)_0444.png', 'S_385 (19)_0445.png', 'S_385 (19)_0446.png', 'S_385 (19)_0447.png', 'S_385 (19)_0448.png', 'S_385 (19)_0451.png', 'S_385 (19)_0452.png', 'S_385 (19)_0453.png ...
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/dataset_ops.py:3350: UserWarning: Even though the tf.config.experimental_run_functions_eagerly option is set, this option does not apply to tf.data functions. tf.data functions are still traced and executed as graphs.
#   "Even though the tf.config.experimental_run_functions_eagerly "

# %%
# Make an iterator to extract images from the tensor dataset
image_batches = tf.compat.v1.data.make_one_shot_iterator(image_tensors)  # outside of TF Eager, we would use make_one_shot_iterator
mask_batches = tf.compat.v1.data.make_one_shot_iterator(masks_tensors)

n_images_to_show = 5

for i in range(n_images_to_show):
    
    # Get the next image from iterator
    image = image_batches.next().numpy().astype(np.uint8)
    mask = mask_batches.next().numpy().astype(np.uint8)
    
    #Plot the corresponding image and masks
    fig = plt.figure()
    fig.add_subplot(1,2,1)
    plt.imshow(image)
    fig.add_subplot(1,2,2)
    plt.imshow(mask)
    plt.show()

# %%
DATA_PATH = '/content/drive/My Drive/segmentation/'

# Create folders to hold images and masks

folders = ['train_image/train', 'train_masks/train', 'val_image/val', 'val_masks/val']


for folder in folders:
    try:
        os.makedirs(DATA_PATH + folder)
    except Exception as e: print(e)
# Out:
# [Errno 17] File exists: '/content/drive/My Drive/segmentation/train_image/train'
# [Errno 17] File exists: '/content/drive/My Drive/segmentation/train_masks/train'
# [Errno 17] File exists: '/content/drive/My Drive/segmentation/val_image/val'
# [Errno 17] File exists: '/content/drive/My Drive/segmentation/val_masks/val'

# %%
def generate_image_folder_structure(image, masks, image_list, masks_list):
    '''Function to save images in the appropriate folder directories 
        Inputs: 
            image - image tensor dataset
            masks - mask tensor dataset
            image_list - image file paths
            masks_list - mask file paths
    '''
    #Create iterators for image and masks
    image_batches = tf.compat.v1.data.make_one_shot_iterator(image)  # outside of TF Eager, we would use make_one_shot_iterator
    mask_batches = tf.compat.v1.data.make_one_shot_iterator(masks)
    
    #Iterate over the train images while saving the image and masks in appropriate folders
    dir_name='train'
    for file in zip(image_list[:-round(0.2*len(image_list))],masks_list[:-round(0.2*len(masks_list))]):
        
        
        #Convert tensors to numpy arrays
        image = image_batches.next().numpy().astype(np.uint8)
        mask = mask_batches.next().numpy().astype(np.uint8)
        
        #Convert numpy arrays to images
        image = Image.fromarray(image)
        mask = Image.fromarray(mask)
        
        #Save image and masks to correct directories
        image.save(DATA_PATH+'{}_image/{}'.format(dir_name,dir_name)+'/'+file[0])
        mask.save(DATA_PATH+'{}_masks/{}'.format(dir_name,dir_name)+'/'+file[1])

         #Iterate over the val images while saving the image and masks in appropriate folders
    dir_name='val'
    for file in zip(image_list[-round(0.2*len(image_list)):],masks_list[-round(0.2*len(masks_list)):]):
        
        
        #Convert tensors to numpy arrays
        image = image_batches.next().numpy().astype(np.uint8)
        mask = mask_batches.next().numpy().astype(np.uint8)
        
        #Convert numpy arrays to images
        image = Image.fromarray(image)
        mask = Image.fromarray(mask)
        
        #Save image and masks to correct directories
        image.save(DATA_PATH+'{}_image/{}'.format(dir_name,dir_name)+'/'+file[0])
        mask.save(DATA_PATH+'{}_masks/{}'.format(dir_name,dir_name)+'/'+file[1])
    
    print("Saved {} image to directory {}".format(len(image_list),DATA_PATH))
    print("Saved {} masks to directory {}".format(len(masks_list),DATA_PATH))
    
generate_image_folder_structure(image_tensors, masks_tensors, image_list, masks_list)

#generate_image_folder_structure(train_image, train_masks, val_files, 'val')
# Out:
# Saved 6095 image to directory /content/drive/My Drive/segmentation/
# Saved 6095 masks to directory /content/drive/My Drive/segmentation/

# %%
label_codes=[(128,0,0),(128,0,128),(0,0,255),(0,128,0),(255,255,0),(255,105,180),(255,0,0),(255,165,0),(128,128,128),(255,255,255)]

# %%
label_names=['Dark_dense_distribution', 'Elongated_nuclei','Light_dense_istribution','Light_distribution',
           'No_nuclei_with_uniform_texture','No_nuclei_with_unstructured','Red_texture',  'Round_nuclei','Mixed','background']

# %%
code2id = {v:k for k,v in enumerate(label_codes)}
id2code = {k:v for k,v in enumerate(label_codes)}

# %%
name2id = {v:k for k,v in enumerate(label_names)}
id2name = {k:v for k,v in enumerate(label_names)}

# %%
id2code
# Out:
# {0: (128, 0, 0),
#  1: (128, 0, 128),
#  2: (0, 0, 255),
#  3: (0, 128, 0),
#  4: (255, 255, 0),
#  5: (255, 105, 180),
#  6: (255, 0, 0),
#  7: (255, 165, 0),
#  8: (128, 128, 128),
#  9: (255, 255, 255)}

# %%
id2name
# Out:
# {0: 'Dark_dense_distribution',
#  1: 'Elongated_nuclei',
#  2: 'Light_dense_istribution',
#  3: 'Light_distribution',
#  4: 'No_nuclei_with_uniform_texture',
#  5: 'No_nuclei_with_unstructured',
#  6: 'Red_texture',
#  7: 'Round_nuclei',
#  8: 'Mixed',
#  9: 'background'}

# %%
def rgb_to_onehot(rgb_image, colormap = id2code):
    '''Function to one hot encode RGB mask labels
        Inputs: 
            rgb_image - image matrix (eg. 256 x 256 x 3 dimension numpy ndarray)
            colormap - dictionary of color to label id
        Output: One hot encoded image of dimensions (height x width x num_classes) where num_classes = len(colormap)
    '''
    num_classes = len(colormap)
    #print('num_classes',num_classes)
    shape = rgb_image.shape[:2]+(num_classes,)
    #print('shape',shape)
    encoded_image = np.zeros( shape, dtype=np.float32)
    #print('encoded image',encoded_image)
    for i, cls in enumerate(colormap):
        encoded_image[:,:,i] = np.all(rgb_image.reshape( (-1,3) ) == colormap[i], axis=1).reshape(shape[:2])
        #print('looping encode',encoded_image)
    return encoded_image


def onehot_to_rgb(onehot, colormap = id2code):
    '''Function to decode encoded mask labels
        Inputs: 
            onehot - one hot encoded image matrix (height x width x num_classes)
            colormap - dictionary of color to label id
        Output: Decoded RGB image (height x width x 3) 
    '''
    #print(f'onehot to rgb{onehot}')
    single_layer = np.argmax(onehot, axis=-1)
    output = np.zeros( onehot.shape[:2]+(3,) )
    for k in colormap.keys():
        output[single_layer==k] = colormap[k]
    return np.float32(output)

# %%
# Normalizing only images, since masks contain label info
data_gen_args = dict(rescale=1./255)
mask_gen_args = dict()

train_image_datagen = ImageDataGenerator(**data_gen_args)
train_masks_datagen = ImageDataGenerator(**mask_gen_args)
val_image_datagen = ImageDataGenerator(**data_gen_args)
val_masks_datagen = ImageDataGenerator(**mask_gen_args)

# Seed defined for aligning images and their masks
seed = 1

# %%
def TrainAugmentGenerator(seed = 1, batch_size = 32):
    '''Train Image data generator
        Inputs: 
            seed - seed provided to the flow_from_directory function to ensure aligned data flow
            batch_size - number of images to import at a time
        Output: Decoded RGB image (height x width x 3) 
    '''
    train_image_generator = train_image_datagen.flow_from_directory(
    DATA_PATH + 'train_image/',
    batch_size = batch_size, seed = seed)

    train_mask_generator = train_masks_datagen.flow_from_directory(
    DATA_PATH + 'train_masks/',
    batch_size = batch_size, seed = seed)

    while True:
        X1i = train_image_generator.next()
        X2i = train_mask_generator.next()
        
        #One hot encoding RGB images
        mask_encoded = [rgb_to_onehot(X2i[0][x,:,:,:], id2code) for x in range(X2i[0].shape[0])]
        
        yield X1i[0], np.asarray(mask_encoded)
        

def ValAugmentGenerator(seed = 1, batch_size = 16):
    '''Validation Image data generator
        Inputs: 
            seed - seed provided to the flow_from_directory function to ensure aligned data flow
            batch_size - number of images to import at a time
        Output: Decoded RGB image (height x width x 3) 
    '''
    val_image_generator = val_image_datagen.flow_from_directory(
    DATA_PATH + 'val_image/',
    batch_size = batch_size, seed = seed)


    val_mask_generator = val_masks_datagen.flow_from_directory(
    DATA_PATH + 'val_masks/',
    batch_size = batch_size, seed = seed)


    while True:
        X1i = val_image_generator.next()
        X2i = val_mask_generator.next()
        
        #One hot encoding RGB images
        mask_encoded = [rgb_to_onehot(X2i[0][x,:,:,:], id2code) for x in range(X2i[0].shape[0])]
        
        yield X1i[0], np.asarray(mask_encoded)

# %%
def get_small_unet(n_filters = 32, bn = True, dilation_rate = 1):
    '''Validation Image data generator
        Inputs: 
            n_filters - base convolution filters
            bn - flag to set batch normalization
            dilation_rate - convolution dilation rate
        Output: Unet keras Model
    '''
    #Define input batch shape
    batch_shape=(256,256,3)
    inputs = Input(batch_shape=(32, 256, 256, 3))
    print(inputs)
    
    conv1 = Conv2D(n_filters * 1, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(inputs)
    if bn:
        conv1 = BatchNormalization()(conv1)
        
    conv1 = Conv2D(n_filters * 1, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(conv1)
    if bn:
        conv1 = BatchNormalization()(conv1)
    
    pool1 = MaxPooling2D(pool_size=(2, 2), data_format='channels_last')(conv1)

    conv2 = Conv2D(n_filters * 2, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(pool1)
    if bn:
        conv2 = BatchNormalization()(conv2)
        
    conv2 = Conv2D(n_filters * 2, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(conv2)
    if bn:
        conv2 = BatchNormalization()(conv2)
    
    pool2 = MaxPooling2D(pool_size=(2, 2), data_format='channels_last')(conv2)

    conv3 = Conv2D(n_filters * 4, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(pool2)
    if bn:
        conv3 = BatchNormalization()(conv3)
        
    conv3 = Conv2D(n_filters * 4, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(conv3)
    if bn:
        conv3 = BatchNormalization()(conv3)
        
    pool3 = MaxPooling2D(pool_size=(2, 2), data_format='channels_last')(conv3)

    conv4 = Conv2D(n_filters * 8, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(pool3)
    if bn:
        conv4 = BatchNormalization()(conv4)
        
    conv4 = Conv2D(n_filters * 8, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(conv4)
    if bn:
        conv4 = BatchNormalization()(conv4)
        
    pool4 = MaxPooling2D(pool_size=(2, 2), data_format='channels_last')(conv4)

    conv5 = Conv2D(n_filters * 16, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(pool4)
    if bn:
        conv5 = BatchNormalization()(conv5)

    conv5 = Conv2D(n_filters * 16, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(conv5)
    if bn:
        conv5 = BatchNormalization()(conv5)
        
    up6 = concatenate([UpSampling2D(size=(2, 2))(conv5), conv4], axis=3)
    
    conv6 = Conv2D(n_filters * 8, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(up6)
    if bn:
        conv6 = BatchNormalization()(conv6)
        
    conv6 = Conv2D(n_filters * 8, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(conv6)
    if bn:
        conv6 = BatchNormalization()(conv6)
        
    up7 = concatenate([UpSampling2D(size=(2, 2))(conv6), conv3], axis=3)
    
    conv7 = Conv2D(n_filters * 4, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(up7)
    if bn:
        conv7 = BatchNormalization()(conv7)
        
    conv7 = Conv2D(n_filters * 4, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(conv7)
    if bn:
        conv7 = BatchNormalization()(conv7)
        
    up8 = concatenate([UpSampling2D(size=(2, 2))(conv7), conv2], axis=3)
    
    conv8 = Conv2D(n_filters * 2, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(up8)
    if bn:
        conv8 = BatchNormalization()(conv8)
        
    conv8 = Conv2D(n_filters * 2, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(conv8)
    if bn:
        conv8 = BatchNormalization()(conv8)

    up9 = concatenate([UpSampling2D(size=(2, 2))(conv8), conv1], axis=3)
    
    conv9 = Conv2D(n_filters * 1, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(up9)
    if bn:
        conv9 = BatchNormalization()(conv9)
        
    conv9 = Conv2D(n_filters * 1, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(conv9)
    if bn:
        conv9 = BatchNormalization()(conv9)
        
    conv10 = Conv2D(10, (1, 1), activation='softmax', padding = 'same', dilation_rate = dilation_rate)(conv9)

    model = Model(inputs=inputs, outputs=conv10)

    
    return model

# %%
model = get_small_unet(n_filters = 10)
# Out:
# Tensor("input_1:0", shape=(32, 256, 256, 3), dtype=float32)

# %%
# Ref: salehi17, "Twersky loss function for image segmentation using 3D FCDN"
# -> the score is computed for each class separately and then summed
# alpha=beta=0.5 : dice coefficient
# alpha=beta=1   : tanimoto coefficient (also known as jaccard)
# alpha+beta=1   : produces set of F*-scores
# implemented by E. Moebel, 06/04/18
def tversky_loss(y_true, y_pred):
    alpha = 0.5
    beta  = 0.5
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2,3))
    den = num + alpha*K.sum(p0*g1,(0,1,2,3)) + beta*K.sum(p1*g0,(0,1,2,3))
    
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f*y_true_f) + K.sum(y_pred_f*y_pred_f) + smooth)


def dice_coef_loss(y_true, y_pred):
    return 1.-dice_coef(y_true, y_pred)

# %%
smooth = 1.

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=[tversky_loss,dice_coef,'accuracy'])

# %%
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(32, 256, 256, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (32, 256, 256, 10)   280         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (32, 256, 256, 10)   40          conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (32, 256, 256, 10)   910         batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (32, 256, 256, 10)   40          conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (32, 128, 128, 10)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (32, 128, 128, 20)   1820        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (32, 128, 128, 20)   80          conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (32, 128, 128, 20)   3620        batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (32, 128, 128, 20)   80          conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (32, 64, 64, 20)     0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (32, 64, 64, 40)     7240        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (32, 64, 64, 40)     160         conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (32, 64, 64, 40)     14440       batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (32, 64, 64, 40)     160         conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (32, 32, 32, 40)     0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (32, 32, 32, 80)     28880       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (32, 32, 32, 80)     320         conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (32, 32, 32, 80)     57680       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (32, 32, 32, 80)     320         conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (32, 16, 16, 80)     0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (32, 16, 16, 160)    115360      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (32, 16, 16, 160)    640         conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (32, 16, 16, 160)    230560      batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (32, 16, 16, 160)    640         conv2d_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (32, 32, 32, 160)    0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (32, 32, 32, 240)    0           up_sampling2d[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (32, 32, 32, 80)     172880      concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (32, 32, 32, 80)     320         conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (32, 32, 32, 80)     57680       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (32, 32, 32, 80)     320         conv2d_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (32, 64, 64, 80)     0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (32, 64, 64, 120)    0           up_sampling2d_1[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (32, 64, 64, 40)     43240       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (32, 64, 64, 40)     160         conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (32, 64, 64, 40)     14440       batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (32, 64, 64, 40)     160         conv2d_13[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (32, 128, 128, 40)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (32, 128, 128, 60)   0           up_sampling2d_2[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (32, 128, 128, 20)   10820       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (32, 128, 128, 20)   80          conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (32, 128, 128, 20)   3620        batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (32, 128, 128, 20)   80          conv2d_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (32, 256, 256, 20)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (32, 256, 256, 30)   0           up_sampling2d_3[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (32, 256, 256, 10)   2710        concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (32, 256, 256, 10)   40          conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (32, 256, 256, 10)   910         batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (32, 256, 256, 10)   40          conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (32, 256, 256, 10)   110         batch_normalization_17[0][0]
# ==================================================================================================
# Total params: 770,880
# Trainable params: 769,040
# Non-trainable params: 1,840
# __________________________________________________________________________________________________

# %%
tb = TensorBoard(log_dir='logs', write_graph=True)
mc = ModelCheckpoint(mode='max', filepath='/content/drive/My Drive/segmentation/segmentation_model_50_val_07th_WITH_epochs_checkpoint.h5', monitor='accuracy', save_best_only='True', save_weights_only='True', verbose=1)
es = EarlyStopping(mode='max', monitor='val_accuracy', patience=50, verbose=1)
callbacks = [tb, mc, es]

# %%
batch_size = 32
steps_per_epoch = np.ceil(float(len(image_list) - round(0.1*len(image_list))) / float(batch_size))
steps_per_epoch
# Out:
# 172.0

# %%
validation_steps = (float((round(0.1*len(image_list)))) / float(batch_size))
validation_steps
# Out:
# 19.0625

# %%
num_epochs = 50

# %%
#model.load_weights("/content/drive/My Drive/Segmentation/segmentation_model_50_epochs.h5")
#loss,acc = model.evaluate(test_images,  test_labels, verbose=2)

# %%
# experimental_run_tf_function=False
# tf.compat.v1.enable_eager_execution()

# %%
# Train model

batch_size = 32
result = model.fit(TrainAugmentGenerator(), steps_per_epoch=steps_per_epoch,
                validation_data = ValAugmentGenerator(), validation_steps = 19 ,epochs=num_epochs, 
                 callbacks=callbacks)
model.save_weights("/content/drive/My Drive/segmentation/segmentation_model_50_val_07th_with_epochs.h5", overwrite=True)
# Out:
# Found 4876 images belonging to 1 classes.
# Found 4876 images belonging to 1 classes.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/dataset_ops.py:3350: UserWarning: Even though the tf.config.experimental_run_functions_eagerly option is set, this option does not apply to tf.data functions. tf.data functions are still traced and executed as graphs.
#   "Even though the tf.config.experimental_run_functions_eagerly "
# Epoch 1/50
#   1/172 [..............................] - ETA: 0s - loss: 2.3292 - tversky_loss: 9.9136 - dice_coef: 0.1554 - accuracy: 0.0863WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# 172/172 [==============================] - ETA: 0s - loss: 0.9151 - tversky_loss: 9.5546 - dice_coef: 0.6711 - accuracy: 0.6055 Found 1219 images belonging to 1 classes.
# Found 1219 images belonging to 1 classes.
#
# Epoch 00001: accuracy improved from -inf to 0.60553, saving model to /content/drive/My Drive/segmentation/segmentation_model_50_val_07th_WITH_epochs_checkpoint.h5
# 172/172 [==============================] - 6068s 35s/step - loss: 0.9151 - tversky_loss: 9.5546 - dice_coef: 0.6711 - accuracy: 0.6055 - val_loss: 0.9961 - val_tversky_loss: 9.4192 - val_dice_coef: 0.7358 - val_accuracy: 0.6201
# Epoch 2/50
# 172/172 [==============================] - ETA: 0s - loss: 0.6378 - tversky_loss: 9.4124 - dice_coef: 0.7836 - accuracy: 0.6536
# Epoch 00002: accuracy improved from 0.60553 to 0.65360, saving model to /content/drive/My Drive/segmentation/segmentation_model_50_val_07th_WITH_epochs_checkpoint.h5
# 172/172 [==============================] - 525s 3s/step - loss: 0.6378 - tversky_loss: 9.4124 - dice_coef: 0.7836 - accuracy: 0.6536 - val_loss: 1.0027 - val_tversky_loss: 9.3392 - val_dice_coef: 0.7696 - val_accuracy: 0.7052
# Epoch 3/50
# 172/172 [==============================] - ETA: 0s - loss: 0.5741 - tversky_loss: 9.3797 - dice_coef: 0.7977 - accuracy: 0.6614
# Epoch 00003: accuracy improved from 0.65360 to 0.66142, saving model to /content/drive/My Drive/segmentation/segmentation_model_50_val_07th_WITH_epochs_checkpoint.h5
# 172/172 [==============================] - 527s 3s/step - loss: 0.5741 - tversky_loss: 9.3797 - dice_coef: 0.7977 - accuracy: 0.6614 - val_loss: 1.5674 - val_tversky_loss: 9.4999 - val_dice_coef: 0.6573 - val_accuracy: 0.5402
# Epoch 4/50
# 172/172 [==============================] - ETA: 0s - loss: 0.5285 - tversky_loss: 9.3560 - dice_coef: 0.8058 - accuracy: 0.6810
# Epoch 00004: accuracy improved from 0.66142 to 0.68104, saving model to /content/drive/My Drive/segmentation/segmentation_model_50_val_07th_WITH_epochs_checkpoint.h5
# 172/172 [==============================] - 453s 3s/step - loss: 0.5285 - tversky_loss: 9.3560 - dice_coef: 0.8058 - accuracy: 0.6810 - val_loss: 1.2350 - val_tversky_loss: 9.3294 - val_dice_coef: 0.7362 - val_accuracy: 0.6817
# Epoch 5/50
# 172/172 [==============================] - ETA: 0s - loss: 0.5154 - tversky_loss: 9.3526 - dice_coef: 0.8038 - accuracy: 0.6714
# Epoch 00005: accuracy did not improve from 0.68104
# 172/172 [==============================] - 158s 921ms/step - loss: 0.5154 - tversky_loss: 9.3526 - dice_coef: 0.8038 - accuracy: 0.6714 - val_loss: 0.8314 - val_tversky_loss: 9.2867 - val_dice_coef: 0.8014 - val_accuracy: 0.7330
# Epoch 6/50
# 172/172 [==============================] - ETA: 0s - loss: 0.4991 - tversky_loss: 9.3435 - dice_coef: 0.8089 - accuracy: 0.6746
# Epoch 00006: accuracy did not improve from 0.68104
# 172/172 [==============================] - 159s 925ms/step - loss: 0.4991 - tversky_loss: 9.3435 - dice_coef: 0.8089 - accuracy: 0.6746 - val_loss: 0.6483 - val_tversky_loss: 9.2620 - val_dice_coef: 0.8343 - val_accuracy: 0.7711
# Epoch 7/50
# 172/172 [==============================] - ETA: 0s - loss: 0.4761 - tversky_loss: 9.3347 - dice_coef: 0.8134 - accuracy: 0.6803
# Epoch 00007: accuracy did not improve from 0.68104
# 172/172 [==============================] - 159s 927ms/step - loss: 0.4761 - tversky_loss: 9.3347 - dice_coef: 0.8134 - accuracy: 0.6803 - val_loss: 1.3643 - val_tversky_loss: 9.5182 - val_dice_coef: 0.6100 - val_accuracy: 0.5885
# Epoch 8/50
# 172/172 [==============================] - ETA: 0s - loss: 0.4545 - tversky_loss: 9.3261 - dice_coef: 0.8138 - accuracy: 0.6827
# Epoch 00008: accuracy improved from 0.68104 to 0.68270, saving model to /content/drive/My Drive/segmentation/segmentation_model_50_val_07th_WITH_epochs_checkpoint.h5
# 172/172 [==============================] - 160s 931ms/step - loss: 0.4545 - tversky_loss: 9.3261 - dice_coef: 0.8138 - accuracy: 0.6827 - val_loss: 0.7971 - val_tversky_loss: 9.3093 - val_dice_coef: 0.8045 - val_accuracy: 0.7226
# Epoch 9/50
# 172/172 [==============================] - ETA: 0s - loss: 0.4560 - tversky_loss: 9.3267 - dice_coef: 0.8146 - accuracy: 0.6836
# Epoch 00009: accuracy improved from 0.68270 to 0.68358, saving model to /content/drive/My Drive/segmentation/segmentation_model_50_val_07th_WITH_epochs_checkpoint.h5
# 172/172 [==============================] - 160s 932ms/step - loss: 0.4560 - tversky_loss: 9.3267 - dice_coef: 0.8146 - accuracy: 0.6836 - val_loss: 0.9761 - val_tversky_loss: 9.4000 - val_dice_coef: 0.7379 - val_accuracy: 0.6956
# Epoch 10/50
# 172/172 [==============================] - ETA: 0s - loss: 0.4505 - tversky_loss: 9.3260 - dice_coef: 0.8163 - accuracy: 0.6828
# Epoch 00010: accuracy did not improve from 0.68358
# 172/172 [==============================] - 159s 925ms/step - loss: 0.4505 - tversky_loss: 9.3260 - dice_coef: 0.8163 - accuracy: 0.6828 - val_loss: 3.4975 - val_tversky_loss: 9.6809 - val_dice_coef: 0.3931 - val_accuracy: 0.3393
# Epoch 11/50
# 172/172 [==============================] - ETA: 0s - loss: 0.4506 - tversky_loss: 9.3256 - dice_coef: 0.8083 - accuracy: 0.6828
# Epoch 00011: accuracy did not improve from 0.68358
# 172/172 [==============================] - 159s 926ms/step - loss: 0.4506 - tversky_loss: 9.3256 - dice_coef: 0.8083 - accuracy: 0.6828 - val_loss: 0.6742 - val_tversky_loss: 9.2597 - val_dice_coef: 0.8336 - val_accuracy: 0.7715
# Epoch 12/50
# 172/172 [==============================] - ETA: 0s - loss: 0.4279 - tversky_loss: 9.3165 - dice_coef: 0.8172 - accuracy: 0.6874
# Epoch 00012: accuracy improved from 0.68358 to 0.68742, saving model to /content/drive/My Drive/segmentation/segmentation_model_50_val_07th_WITH_epochs_checkpoint.h5
# 172/172 [==============================] - 161s 933ms/step - loss: 0.4279 - tversky_loss: 9.3165 - dice_coef: 0.8172 - accuracy: 0.6874 - val_loss: 1.2047 - val_tversky_loss: 9.3587 - val_dice_coef: 0.7333 - val_accuracy: 0.6482
# Epoch 13/50
# 172/172 [==============================] - ETA: 0s - loss: 0.4341 - tversky_loss: 9.3191 - dice_coef: 0.8118 - accuracy: 0.6841
# Epoch 00013: accuracy did not improve from 0.68742
# 172/172 [==============================] - 160s 929ms/step - loss: 0.4341 - tversky_loss: 9.3191 - dice_coef: 0.8118 - accuracy: 0.6841 - val_loss: 1.0490 - val_tversky_loss: 9.3507 - val_dice_coef: 0.7619 - val_accuracy: 0.6790
# Epoch 14/50
# 172/172 [==============================] - ETA: 0s - loss: 0.4208 - tversky_loss: 9.3140 - dice_coef: 0.8155 - accuracy: 0.6867
# Epoch 00014: accuracy did not improve from 0.68742
# 172/172 [==============================] - 160s 928ms/step - loss: 0.4208 - tversky_loss: 9.3140 - dice_coef: 0.8155 - accuracy: 0.6867 - val_loss: 0.6411 - val_tversky_loss: 9.3090 - val_dice_coef: 0.8192 - val_accuracy: 0.7450
# Epoch 15/50
# 172/172 [==============================] - ETA: 0s - loss: 0.4195 - tversky_loss: 9.3108 - dice_coef: 0.8141 - accuracy: 0.6937
# Epoch 00015: accuracy improved from 0.68742 to 0.69366, saving model to /content/drive/My Drive/segmentation/segmentation_model_50_val_07th_WITH_epochs_checkpoint.h5
# 172/172 [==============================] - 160s 931ms/step - loss: 0.4195 - tversky_loss: 9.3108 - dice_coef: 0.8141 - accuracy: 0.6937 - val_loss: 0.8331 - val_tversky_loss: 9.3423 - val_dice_coef: 0.7686 - val_accuracy: 0.6825
# Epoch 16/50
# 172/172 [==============================] - ETA: 0s - loss: 0.4108 - tversky_loss: 9.3093 - dice_coef: 0.8182 - accuracy: 0.6907
# Epoch 00016: accuracy did not improve from 0.69366
# 172/172 [==============================] - 159s 927ms/step - loss: 0.4108 - tversky_loss: 9.3093 - dice_coef: 0.8182 - accuracy: 0.6907 - val_loss: 2.4927 - val_tversky_loss: 9.6102 - val_dice_coef: 0.5033 - val_accuracy: 0.4357
# Epoch 17/50
# 172/172 [==============================] - ETA: 0s - loss: 0.4082 - tversky_loss: 9.3075 - dice_coef: 0.8195 - accuracy: 0.6929
# Epoch 00017: accuracy did not improve from 0.69366
# 172/172 [==============================] - 159s 923ms/step - loss: 0.4082 - tversky_loss: 9.3075 - dice_coef: 0.8195 - accuracy: 0.6929 - val_loss: 0.7463 - val_tversky_loss: 9.3283 - val_dice_coef: 0.7990 - val_accuracy: 0.6936
# Epoch 18/50
# 172/172 [==============================] - ETA: 0s - loss: 0.4052 - tversky_loss: 9.3071 - dice_coef: 0.8176 - accuracy: 0.6914
# Epoch 00018: accuracy did not improve from 0.69366
# 172/172 [==============================] - 159s 925ms/step - loss: 0.4052 - tversky_loss: 9.3071 - dice_coef: 0.8176 - accuracy: 0.6914 - val_loss: 0.7295 - val_tversky_loss: 9.2662 - val_dice_coef: 0.8198 - val_accuracy: 0.7561
# Epoch 19/50
# 172/172 [==============================] - ETA: 0s - loss: 0.3892 - tversky_loss: 9.3019 - dice_coef: 0.8169 - accuracy: 0.6961
# Epoch 00019: accuracy improved from 0.69366 to 0.69605, saving model to /content/drive/My Drive/segmentation/segmentation_model_50_val_07th_WITH_epochs_checkpoint.h5
# 172/172 [==============================] - 161s 934ms/step - loss: 0.3892 - tversky_loss: 9.3019 - dice_coef: 0.8169 - accuracy: 0.6961 - val_loss: 0.6483 - val_tversky_loss: 9.2512 - val_dice_coef: 0.8384 - val_accuracy: 0.7767
# Epoch 20/50
# 172/172 [==============================] - ETA: 0s - loss: 0.4101 - tversky_loss: 9.3059 - dice_coef: 0.8178 - accuracy: 0.6951
# Epoch 00020: accuracy did not improve from 0.69605
# 172/172 [==============================] - 160s 931ms/step - loss: 0.4101 - tversky_loss: 9.3059 - dice_coef: 0.8178 - accuracy: 0.6951 - val_loss: 2.1072 - val_tversky_loss: 9.6635 - val_dice_coef: 0.4451 - val_accuracy: 0.3313
# Epoch 21/50
# 172/172 [==============================] - ETA: 0s - loss: 0.3911 - tversky_loss: 9.3002 - dice_coef: 0.8199 - accuracy: 0.6959
# Epoch 00021: accuracy did not improve from 0.69605
# 172/172 [==============================] - 161s 937ms/step - loss: 0.3911 - tversky_loss: 9.3002 - dice_coef: 0.8199 - accuracy: 0.6959 - val_loss: 0.6797 - val_tversky_loss: 9.2796 - val_dice_coef: 0.8304 - val_accuracy: 0.7754
# Epoch 22/50
# 172/172 [==============================] - ETA: 0s - loss: 0.3816 - tversky_loss: 9.2997 - dice_coef: 0.8216 - accuracy: 0.6940
# Epoch 00022: accuracy did not improve from 0.69605
# 172/172 [==============================] - 160s 933ms/step - loss: 0.3816 - tversky_loss: 9.2997 - dice_coef: 0.8216 - accuracy: 0.6940 - val_loss: 0.7824 - val_tversky_loss: 9.3060 - val_dice_coef: 0.8038 - val_accuracy: 0.7226
# Epoch 23/50
# 172/172 [==============================] - ETA: 0s - loss: 0.3816 - tversky_loss: 9.2964 - dice_coef: 0.8240 - accuracy: 0.7001
# Epoch 00023: accuracy improved from 0.69605 to 0.70009, saving model to /content/drive/My Drive/segmentation/segmentation_model_50_val_07th_WITH_epochs_checkpoint.h5
# 172/172 [==============================] - 160s 930ms/step - loss: 0.3816 - tversky_loss: 9.2964 - dice_coef: 0.8240 - accuracy: 0.7001 - val_loss: 0.6429 - val_tversky_loss: 9.2883 - val_dice_coef: 0.8295 - val_accuracy: 0.7490
# Epoch 24/50
# 172/172 [==============================] - ETA: 0s - loss: 0.3808 - tversky_loss: 9.2964 - dice_coef: 0.8269 - accuracy: 0.6983
# Epoch 00024: accuracy did not improve from 0.70009
# 172/172 [==============================] - 159s 927ms/step - loss: 0.3808 - tversky_loss: 9.2964 - dice_coef: 0.8269 - accuracy: 0.6983 - val_loss: 0.6032 - val_tversky_loss: 9.2420 - val_dice_coef: 0.8485 - val_accuracy: 0.7783
# Epoch 25/50
# 172/172 [==============================] - ETA: 0s - loss: 0.3814 - tversky_loss: 9.2948 - dice_coef: 0.8239 - accuracy: 0.6998
# Epoch 00025: accuracy did not improve from 0.70009
# 172/172 [==============================] - 159s 922ms/step - loss: 0.3814 - tversky_loss: 9.2948 - dice_coef: 0.8239 - accuracy: 0.6998 - val_loss: 0.8657 - val_tversky_loss: 9.3063 - val_dice_coef: 0.7934 - val_accuracy: 0.7174
# Epoch 26/50
# 172/172 [==============================] - ETA: 0s - loss: 0.3808 - tversky_loss: 9.2949 - dice_coef: 0.8215 - accuracy: 0.6998
# Epoch 00026: accuracy did not improve from 0.70009
# 172/172 [==============================] - 159s 924ms/step - loss: 0.3808 - tversky_loss: 9.2949 - dice_coef: 0.8215 - accuracy: 0.6998 - val_loss: 0.7326 - val_tversky_loss: 9.3251 - val_dice_coef: 0.8035 - val_accuracy: 0.7276
# Epoch 27/50
# 172/172 [==============================] - ETA: 0s - loss: 0.3656 - tversky_loss: 9.2928 - dice_coef: 0.8254 - accuracy: 0.7008
# Epoch 00027: accuracy improved from 0.70009 to 0.70081, saving model to /content/drive/My Drive/segmentation/segmentation_model_50_val_07th_WITH_epochs_checkpoint.h5
# 172/172 [==============================] - 160s 928ms/step - loss: 0.3656 - tversky_loss: 9.2928 - dice_coef: 0.8254 - accuracy: 0.7008 - val_loss: 1.8494 - val_tversky_loss: 9.5879 - val_dice_coef: 0.5033 - val_accuracy: 0.4083
# Epoch 28/50
# 172/172 [==============================] - ETA: 0s - loss: 0.3757 - tversky_loss: 9.2930 - dice_coef: 0.8242 - accuracy: 0.7014
# Epoch 00028: accuracy improved from 0.70081 to 0.70137, saving model to /content/drive/My Drive/segmentation/segmentation_model_50_val_07th_WITH_epochs_checkpoint.h5
# 172/172 [==============================] - 161s 938ms/step - loss: 0.3757 - tversky_loss: 9.2930 - dice_coef: 0.8242 - accuracy: 0.7014 - val_loss: 0.8066 - val_tversky_loss: 9.2828 - val_dice_coef: 0.8084 - val_accuracy: 0.7357
# Epoch 29/50
# 172/172 [==============================] - ETA: 0s - loss: 0.3620 - tversky_loss: 9.2860 - dice_coef: 0.8300 - accuracy: 0.7042
# Epoch 00029: accuracy improved from 0.70137 to 0.70424, saving model to /content/drive/My Drive/segmentation/segmentation_model_50_val_07th_WITH_epochs_checkpoint.h5
# 172/172 [==============================] - 162s 940ms/step - loss: 0.3620 - tversky_loss: 9.2860 - dice_coef: 0.8300 - accuracy: 0.7042 - val_loss: 1.9396 - val_tversky_loss: 9.6565 - val_dice_coef: 0.4489 - val_accuracy: 0.3563
# Epoch 30/50
# 172/172 [==============================] - ETA: 0s - loss: 0.3617 - tversky_loss: 9.2884 - dice_coef: 0.8279 - accuracy: 0.7028
# Epoch 00030: accuracy did not improve from 0.70424
# 172/172 [==============================] - 160s 929ms/step - loss: 0.3617 - tversky_loss: 9.2884 - dice_coef: 0.8279 - accuracy: 0.7028 - val_loss: 0.6926 - val_tversky_loss: 9.2413 - val_dice_coef: 0.8331 - val_accuracy: 0.7876
# Epoch 31/50
# 172/172 [==============================] - ETA: 0s - loss: 0.3563 - tversky_loss: 9.2854 - dice_coef: 0.8315 - accuracy: 0.7045
# Epoch 00031: accuracy improved from 0.70424 to 0.70449, saving model to /content/drive/My Drive/segmentation/segmentation_model_50_val_07th_WITH_epochs_checkpoint.h5
# 172/172 [==============================] - 166s 963ms/step - loss: 0.3563 - tversky_loss: 9.2854 - dice_coef: 0.8315 - accuracy: 0.7045 - val_loss: 0.6315 - val_tversky_loss: 9.2442 - val_dice_coef: 0.8440 - val_accuracy: 0.7751
# Epoch 32/50
# 172/172 [==============================] - ETA: 0s - loss: 0.3515 - tversky_loss: 9.2831 - dice_coef: 0.8306 - accuracy: 0.7056
# Epoch 00032: accuracy improved from 0.70449 to 0.70555, saving model to /content/drive/My Drive/segmentation/segmentation_model_50_val_07th_WITH_epochs_checkpoint.h5
# 172/172 [==============================] - 167s 974ms/step - loss: 0.3515 - tversky_loss: 9.2831 - dice_coef: 0.8306 - accuracy: 0.7056 - val_loss: 0.7031 - val_tversky_loss: 9.3019 - val_dice_coef: 0.8081 - val_accuracy: 0.7112
# Epoch 33/50
# 172/172 [==============================] - ETA: 0s - loss: 0.3460 - tversky_loss: 9.2806 - dice_coef: 0.8311 - accuracy: 0.7076
# Epoch 00033: accuracy improved from 0.70555 to 0.70760, saving model to /content/drive/My Drive/segmentation/segmentation_model_50_val_07th_WITH_epochs_checkpoint.h5
# 172/172 [==============================] - 168s 977ms/step - loss: 0.3460 - tversky_loss: 9.2806 - dice_coef: 0.8311 - accuracy: 0.7076 - val_loss: 1.4612 - val_tversky_loss: 9.5247 - val_dice_coef: 0.6142 - val_accuracy: 0.5396
# Epoch 34/50
# 172/172 [==============================] - ETA: 0s - loss: 0.3436 - tversky_loss: 9.2799 - dice_coef: 0.8312 - accuracy: 0.7089
# Epoch 00034: accuracy improved from 0.70760 to 0.70892, saving model to /content/drive/My Drive/segmentation/segmentation_model_50_val_07th_WITH_epochs_checkpoint.h5
# 172/172 [==============================] - 166s 967ms/step - loss: 0.3436 - tversky_loss: 9.2799 - dice_coef: 0.8312 - accuracy: 0.7089 - val_loss: 1.1994 - val_tversky_loss: 9.3550 - val_dice_coef: 0.7328 - val_accuracy: 0.6550
# Epoch 35/50
# 172/172 [==============================] - ETA: 0s - loss: 0.3431 - tversky_loss: 9.2794 - dice_coef: 0.8296 - accuracy: 0.7078
# Epoch 00035: accuracy did not improve from 0.70892
# 172/172 [==============================] - 164s 956ms/step - loss: 0.3431 - tversky_loss: 9.2794 - dice_coef: 0.8296 - accuracy: 0.7078 - val_loss: 0.8264 - val_tversky_loss: 9.2591 - val_dice_coef: 0.8201 - val_accuracy: 0.7555
# Epoch 36/50
# 172/172 [==============================] - ETA: 0s - loss: 0.3477 - tversky_loss: 9.2791 - dice_coef: 0.8319 - accuracy: 0.7082
# Epoch 00036: accuracy did not improve from 0.70892
# 172/172 [==============================] - 163s 946ms/step - loss: 0.3477 - tversky_loss: 9.2791 - dice_coef: 0.8319 - accuracy: 0.7082 - val_loss: 0.8013 - val_tversky_loss: 9.3087 - val_dice_coef: 0.7970 - val_accuracy: 0.7016
# Epoch 37/50
# 172/172 [==============================] - ETA: 0s - loss: 0.3397 - tversky_loss: 9.2768 - dice_coef: 0.8328 - accuracy: 0.7114
# Epoch 00037: accuracy improved from 0.70892 to 0.71136, saving model to /content/drive/My Drive/segmentation/segmentation_model_50_val_07th_WITH_epochs_checkpoint.h5
# 172/172 [==============================] - 163s 950ms/step - loss: 0.3397 - tversky_loss: 9.2768 - dice_coef: 0.8328 - accuracy: 0.7114 - val_loss: 1.4249 - val_tversky_loss: 9.5798 - val_dice_coef: 0.5773 - val_accuracy: 0.5357
# Epoch 38/50
# 172/172 [==============================] - ETA: 0s - loss: 0.3500 - tversky_loss: 9.2819 - dice_coef: 0.8275 - accuracy: 0.7065
# Epoch 00038: accuracy did not improve from 0.71136
# 172/172 [==============================] - 161s 936ms/step - loss: 0.3500 - tversky_loss: 9.2819 - dice_coef: 0.8275 - accuracy: 0.7065 - val_loss: 0.6619 - val_tversky_loss: 9.2587 - val_dice_coef: 0.8312 - val_accuracy: 0.7715
# Epoch 39/50
# 172/172 [==============================] - ETA: 0s - loss: 0.3252 - tversky_loss: 9.2736 - dice_coef: 0.8341 - accuracy: 0.7116
# Epoch 00039: accuracy improved from 0.71136 to 0.71163, saving model to /content/drive/My Drive/segmentation/segmentation_model_50_val_07th_WITH_epochs_checkpoint.h5
# 172/172 [==============================] - 161s 938ms/step - loss: 0.3252 - tversky_loss: 9.2736 - dice_coef: 0.8341 - accuracy: 0.7116 - val_loss: 0.8909 - val_tversky_loss: 9.3221 - val_dice_coef: 0.7825 - val_accuracy: 0.7003
# Epoch 40/50
# 172/172 [==============================] - ETA: 0s - loss: 0.3277 - tversky_loss: 9.2704 - dice_coef: 0.8340 - accuracy: 0.7153
# Epoch 00040: accuracy improved from 0.71163 to 0.71529, saving model to /content/drive/My Drive/segmentation/segmentation_model_50_val_07th_WITH_epochs_checkpoint.h5
# 172/172 [==============================] - 161s 935ms/step - loss: 0.3277 - tversky_loss: 9.2704 - dice_coef: 0.8340 - accuracy: 0.7153 - val_loss: 0.9522 - val_tversky_loss: 9.3049 - val_dice_coef: 0.7836 - val_accuracy: 0.7018
# Epoch 41/50
# 172/172 [==============================] - ETA: 0s - loss: 0.3270 - tversky_loss: 9.2711 - dice_coef: 0.8365 - accuracy: 0.7153
# Epoch 00041: accuracy improved from 0.71529 to 0.71529, saving model to /content/drive/My Drive/segmentation/segmentation_model_50_val_07th_WITH_epochs_checkpoint.h5
# 172/172 [==============================] - 161s 938ms/step - loss: 0.3270 - tversky_loss: 9.2711 - dice_coef: 0.8365 - accuracy: 0.7153 - val_loss: 0.8120 - val_tversky_loss: 9.3388 - val_dice_coef: 0.7651 - val_accuracy: 0.6849
# Epoch 42/50
# 172/172 [==============================] - ETA: 0s - loss: 0.3238 - tversky_loss: 9.2704 - dice_coef: 0.8375 - accuracy: 0.7141
# Epoch 00042: accuracy did not improve from 0.71529
# 172/172 [==============================] - 160s 932ms/step - loss: 0.3238 - tversky_loss: 9.2704 - dice_coef: 0.8375 - accuracy: 0.7141 - val_loss: 0.7257 - val_tversky_loss: 9.2319 - val_dice_coef: 0.8312 - val_accuracy: 0.7848
# Epoch 43/50
# 172/172 [==============================] - ETA: 0s - loss: 0.3099 - tversky_loss: 9.2663 - dice_coef: 0.8366 - accuracy: 0.7155
# Epoch 00043: accuracy improved from 0.71529 to 0.71554, saving model to /content/drive/My Drive/segmentation/segmentation_model_50_val_07th_WITH_epochs_checkpoint.h5
# 172/172 [==============================] - 161s 935ms/step - loss: 0.3099 - tversky_loss: 9.2663 - dice_coef: 0.8366 - accuracy: 0.7155 - val_loss: 0.6411 - val_tversky_loss: 9.2711 - val_dice_coef: 0.8366 - val_accuracy: 0.7727
# Epoch 44/50
# 172/172 [==============================] - ETA: 0s - loss: 0.3249 - tversky_loss: 9.2667 - dice_coef: 0.8375 - accuracy: 0.7198
# Epoch 00044: accuracy improved from 0.71554 to 0.71978, saving model to /content/drive/My Drive/segmentation/segmentation_model_50_val_07th_WITH_epochs_checkpoint.h5
# 172/172 [==============================] - 161s 936ms/step - loss: 0.3249 - tversky_loss: 9.2667 - dice_coef: 0.8375 - accuracy: 0.7198 - val_loss: 0.6681 - val_tversky_loss: 9.2151 - val_dice_coef: 0.8547 - val_accuracy: 0.8060
# Epoch 45/50
# 172/172 [==============================] - ETA: 0s - loss: 0.3083 - tversky_loss: 9.2652 - dice_coef: 0.8398 - accuracy: 0.7166
# Epoch 00045: accuracy did not improve from 0.71978
# 172/172 [==============================] - 159s 924ms/step - loss: 0.3083 - tversky_loss: 9.2652 - dice_coef: 0.8398 - accuracy: 0.7166 - val_loss: 0.8816 - val_tversky_loss: 9.3042 - val_dice_coef: 0.7906 - val_accuracy: 0.7190
# Epoch 46/50
# 172/172 [==============================] - ETA: 0s - loss: 0.3083 - tversky_loss: 9.2606 - dice_coef: 0.8410 - accuracy: 0.7213
# Epoch 00046: accuracy improved from 0.71978 to 0.72130, saving model to /content/drive/My Drive/segmentation/segmentation_model_50_val_07th_WITH_epochs_checkpoint.h5
# 172/172 [==============================] - 160s 931ms/step - loss: 0.3083 - tversky_loss: 9.2606 - dice_coef: 0.8410 - accuracy: 0.7213 - val_loss: 0.7649 - val_tversky_loss: 9.3129 - val_dice_coef: 0.7988 - val_accuracy: 0.7130
# Epoch 47/50
# 172/172 [==============================] - ETA: 0s - loss: 0.3072 - tversky_loss: 9.2638 - dice_coef: 0.8395 - accuracy: 0.7161
# Epoch 00047: accuracy did not improve from 0.72130
# 172/172 [==============================] - 159s 925ms/step - loss: 0.3072 - tversky_loss: 9.2638 - dice_coef: 0.8395 - accuracy: 0.7161 - val_loss: 1.1346 - val_tversky_loss: 9.3940 - val_dice_coef: 0.7256 - val_accuracy: 0.6533
# Epoch 48/50
# 172/172 [==============================] - ETA: 0s - loss: 0.3069 - tversky_loss: 9.2624 - dice_coef: 0.8399 - accuracy: 0.7209
# Epoch 00048: accuracy did not improve from 0.72130
# 172/172 [==============================] - 159s 926ms/step - loss: 0.3069 - tversky_loss: 9.2624 - dice_coef: 0.8399 - accuracy: 0.7209 - val_loss: 0.8255 - val_tversky_loss: 9.2858 - val_dice_coef: 0.8041 - val_accuracy: 0.7357
# Epoch 49/50
# 172/172 [==============================] - ETA: 0s - loss: 0.3042 - tversky_loss: 9.2625 - dice_coef: 0.8409 - accuracy: 0.7201
# Epoch 00049: accuracy did not improve from 0.72130
# 172/172 [==============================] - 158s 921ms/step - loss: 0.3042 - tversky_loss: 9.2625 - dice_coef: 0.8409 - accuracy: 0.7201 - val_loss: 0.8649 - val_tversky_loss: 9.3119 - val_dice_coef: 0.7941 - val_accuracy: 0.7145
# Epoch 50/50
# 172/172 [==============================] - ETA: 0s - loss: 0.2921 - tversky_loss: 9.2565 - dice_coef: 0.8429 - accuracy: 0.7240
# Epoch 00050: accuracy improved from 0.72130 to 0.72400, saving model to /content/drive/My Drive/segmentation/segmentation_model_50_val_07th_WITH_epochs_checkpoint.h5
# 172/172 [==============================] - 161s 935ms/step - loss: 0.2921 - tversky_loss: 9.2565 - dice_coef: 0.8429 - accuracy: 0.7240 - val_loss: 0.9701 - val_tversky_loss: 9.3170 - val_dice_coef: 0.7778 - val_accuracy: 0.7043

# %%
# Get actual number of epochs model was trained for
N = len(result.history['loss'])

#Plot the model evaluation history
plt.style.use("ggplot")
fig = plt.figure(figsize=(20,8))

fig.add_subplot(1,2,1)
plt.title("Training Loss")
plt.plot(np.arange(0, N), result.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), result.history["val_loss"], label="val_loss")
plt.ylim(0, 1)

plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend(loc="lower left")

fig.add_subplot(1,2,2)
plt.title("Training Accuracy")
plt.plot(np.arange(0, N), result.history["accuracy"], label="train_accuracy")
plt.plot(np.arange(0, N), result.history["val_accuracy"], label="val_accuracy")
plt.ylim(0, 1)

plt.xlabel("Epoch #")
plt.ylabel("Accuracy")
plt.legend(loc="lower left")
plt.show()

# %%
# Get actual number of epochs model was trained for
N = len(result.history['dice_coef'])

#Plot the model evaluation history
plt.style.use("ggplot")
fig = plt.figure(figsize=(20,8))

fig.add_subplot(1,2,1)
plt.title("dice_coef")
plt.plot(np.arange(0, N), result.history["dice_coef"], label="dice_coef")
plt.plot(np.arange(0, N), result.history["val_dice_coef"], label="val_dice_coef")
plt.ylim(0, 1)

plt.xlabel("Epoch #")
plt.ylabel("dice_coef")
plt.legend(loc="lower left")
plt.show()
# fig.add_subplot(1,2,2)
# plt.title("Training Accuracy")
# plt.plot(np.arange(0, N), result.history["accuracy"], label="train_accuracy")
# plt.plot(np.arange(0, N), result.history["val_accuracy"], label="val_accuracy")
# plt.ylim(0, 1)

# plt.xlabel("Epoch #")
# plt.ylabel("Loss/Accuracy")
# plt.legend(loc="lower left")
# plt.show()

# %%
#training_gen = TrainAugmentGenerator()
testing_gen = ValAugmentGenerator()

# %%
# test_eval = model.evaluate_generator(testing_gen,steps = len(testing_gen), verbose=1)
# test_generator.reset()

# %%
batch_img,batch_mask = next(testing_gen)
#batch_img,batch_mask = next(training_gen)
pred_all= model.predict(batch_img)
#print(batch_mask)
np.shape(pred_all)
# Out:
# Found 1219 images belonging to 1 classes.
# Found 1219 images belonging to 1 classes.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/dataset_ops.py:3350: UserWarning: Even though the tf.config.experimental_run_functions_eagerly option is set, this option does not apply to tf.data functions. tf.data functions are still traced and executed as graphs.
#   "Even though the tf.config.experimental_run_functions_eagerly "
# (16, 256, 256, 10)

# %%
#acc = model.evaluate(batch_img, batch_mask, verbose=2)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/dataset_ops.py:3350: UserWarning: Even though the tf.config.experimental_run_functions_eagerly option is set, this option does not apply to tf.data functions. tf.data functions are still traced and executed as graphs.
#   "Even though the tf.config.experimental_run_functions_eagerly "
# 1/1 - 0s - loss: 0.2368 - tversky_loss: 9.3598 - dice_coef: 0.8105 - accuracy: 0.5842
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-5cacddff8ca6> in <module>()
# ----> 1 loss,acc = model.evaluate(batch_img, batch_mask, verbose=2)
#
# ValueError: too many values to unpack (expected 2)

# %%
for i in range(0,np.shape(pred_all)[0]):
    
    fig = plt.figure(figsize=(20,8))
    
    ax1 = fig.add_subplot(1,3,1)
    ax1.imshow(batch_img[i])
    ax1.title.set_text('Actual image')
    ax1.grid(b=None)
    
    
    ax2 = fig.add_subplot(1,3,2)
    ax2.set_title('Ground truth labels')
    ax2.imshow(onehot_to_rgb(batch_mask[i],id2code))
    #ax2.imshow()
    ax2.grid(b=None)
    
    ax3 = fig.add_subplot(1,3,3)
    ax3.set_title('Predicted labels')
    ax3.imshow(onehot_to_rgb(pred_all[i],id2code))
    ax3.grid(b=None)
    
    plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#tf.compat.v1.enable_eager_execution()

# %%
acc = model.evaluate(batch_img, batch_mask, verbose=2)
# Out:
# 1/1 - 0s - loss: 1.3764 - tversky_loss: 9.3963 - dice_coef: 0.7082 - accuracy: 0.6314
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/dataset_ops.py:3350: UserWarning: Even though the tf.config.experimental_run_functions_eagerly option is set, this option does not apply to tf.data functions. tf.data functions are still traced and executed as graphs.
#   "Even though the tf.config.experimental_run_functions_eagerly "

# %%
'''latest good results
43/43 [==============================] - ETA: 0s - loss: 0.2861 - tversky_loss: 9.2378 - dice_coef: 0.8718 - accuracy: 0.7566
Epoch 00050: accuracy improved from 0.75591 to 0.75656, saving model to /content/drive/My Drive/segmentation/segmentation_model_50_with_norm_epochs_checkpoint.h5
43/43 [==============================] - 56s 1s/step - loss: 0.2861 - tversky_loss: 9.2378 - dice_coef: 0.8718 - accuracy: 0.7566 - val_loss: 0.6213 - val_tversky_loss: 9.3738 - val_dice_coef: 0.7534 - val_accuracy: 0.5767


test
loss: 0.1370 - tversky_loss: 9.2932 - dice_coef: 0.8461 - accuracy: 0.6068

'''
