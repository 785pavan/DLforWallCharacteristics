# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %%
from __future__ import print_function, division, absolute_import, unicode_literals
# %load_ext tensorboard
import tensorflow as tf
print(tf.__version__)
tf.config.list_physical_devices('GPU')
# Out:
# 2.1.0
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# !nvidia-smi
# Out:
# Mon Feb 17 16:06:06 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.48.02    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    25W / 250W |     10MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from tqdm import tqdm_notebook, tnrange
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split
from PIL import ImageOps, Image
from sklearn.cluster import KMeans
from time import time
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, BatchNormalization, Activation, Dense, Dropout
from tensorflow.keras.layers import Lambda, RepeatVector, Reshape
from tensorflow.keras.layers import Conv2D, Conv2DTranspose
from tensorflow.keras.layers import MaxPooling2D, GlobalMaxPool2D
from tensorflow.keras.layers import concatenate, add
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
print('setup finished')
# Out:
# setup finished

# %% [markdown]
# # Setting perameters

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
im_width = 128
im_height = 128
path_train = r'/content/drive/My Drive/WALL_SEG/'
classes = ['dark_dense_distribution', 'Elongated_nuclei','light_dense_istribution','light_distribution',
           'No_nuclei_with_uniform_texture','No_nuclei_with_unstructured','Red_texture',  'Round_nuclei','Mixed']

# %%
path_train + 'images'
# Out:
# '/content/drive/My Drive/WALL_SEG/images'

# %%
def one_hot_encode( mask, palette):
        """
        Converts mask to a one-hot encoding specified by the semantic map.
        """
        one_hot_map = []
        for colour in palette:
            class_map = tf.reduce_all(tf.equal(mask, colour), axis=-1)
            one_hot_map.append(class_map)
        one_hot_map = tf.stack(one_hot_map, axis=-1)
        one_hot_map = tf.cast(one_hot_map, tf.float32)
        
        return one_hot_map

# %%
def patch_maker(savedir, path, filename, target_size=(256,256)):
    
    '''opens one images at a time and saves them into patches of given hight and width. 
    It also handels RGBA format issues'''
    if not os.path.isdir(savedir):
            os.mkdir(savedir)
    img = Image.open(path + filename)
    width, height = img.size

    start_pos = start_x, start_y = (0, 0)
    cropped_image_size = w, h = target_size

    new_name = filename.split('.')[0]
    frame_num = 1
    for col_i in tqdm_notebook(range(0, width, w)):
        for row_i in range(0, height, h):
            crop = img.crop((col_i, row_i, col_i + w, row_i + h))
            save_to= os.path.join(savedir, new_name + "_{:04}.jpg")
            if crop.mode in ('RGBA', 'LA'):
                background = Image.new(crop.mode[:-1], crop.size, (255,255,255))
                background.paste(crop, crop.split()[-1])
                crop = background
            crop.save(save_to.format(frame_num))
            frame_num += 1

# %%
def save_patches(savedir, path, images, masks):
    if not os.path.isdir(savedir):
            os.makedirs(savedir)
    path_im = path + images
    path_ms = path + masks 
    ids = next(os.walk(path_ms))[2]
    for n, id_ in tqdm_notebook(enumerate(ids), total=len(ids)):
        '''image pathing'''
        print(id_.replace('.png', ''))
        patch_maker(savedir + 'images/images', path_im, id_.replace('.png', '.tif'))
        
        '''mask patching'''
        patch_maker(savedir + 'masks/masks', path_ms, id_)

# %% [markdown]
# # only run this cell if you dont have patches

# %%
# patches for images 
save_patches('/tmp/training/patches/',path_train, 'Images/', 'Masks/')
# Out:
# HBox(children=(IntProgress(value=0, max=24), HTML(value='')))
# S_385 (28).tif
# HBox(children=(IntProgress(value=0, max=35), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=35), HTML(value='')))
# S_385 (31).tif
# HBox(children=(IntProgress(value=0, max=29), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=29), HTML(value='')))
# S_385 (32).tif
# HBox(children=(IntProgress(value=0, max=29), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=29), HTML(value='')))
# S_385 (33).tif
# HBox(children=(IntProgress(value=0, max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=19), HTML(value='')))
# S_385 (34).tif
# HBox(children=(IntProgress(value=0, max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=16), HTML(value='')))
# S_385 (35).tif
# HBox(children=(IntProgress(value=0, max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=15), HTML(value='')))
# S_385 (14).tif
# HBox(children=(IntProgress(value=0, max=28), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=28), HTML(value='')))
# S_385 (15).tif
# HBox(children=(IntProgress(value=0, max=34), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=34), HTML(value='')))
# S_385 (16).tif
# HBox(children=(IntProgress(value=0, max=34), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=34), HTML(value='')))
# S_385 (17).tif
# HBox(children=(IntProgress(value=0, max=34), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=34), HTML(value='')))
# S_385 (18).tif
# HBox(children=(IntProgress(value=0, max=36), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=36), HTML(value='')))
# S_385 (19).tif
# HBox(children=(IntProgress(value=0, max=35), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=35), HTML(value='')))
# S_385 (20).tif
# HBox(children=(IntProgress(value=0, max=35), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=35), HTML(value='')))
# S_385 (21).tif
# HBox(children=(IntProgress(value=0, max=35), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=35), HTML(value='')))
# S_385 (22).tif
# HBox(children=(IntProgress(value=0, max=36), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=36), HTML(value='')))
# S_385 (23).tif
# HBox(children=(IntProgress(value=0, max=35), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=35), HTML(value='')))
# S_385 (24).tif
# HBox(children=(IntProgress(value=0, max=36), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=36), HTML(value='')))
# S_385 (25).tif
# HBox(children=(IntProgress(value=0, max=37), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=37), HTML(value='')))
# S_385 (26).tif
# HBox(children=(IntProgress(value=0, max=32), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=32), HTML(value='')))
# S_385 (27).tif
# HBox(children=(IntProgress(value=0, max=37), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=37), HTML(value='')))
# S_385 (29).tif
# HBox(children=(IntProgress(value=0, max=33), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=33), HTML(value='')))
# S_385 (30).tif
# HBox(children=(IntProgress(value=0, max=36), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=36), HTML(value='')))
# S_385 (66).tif
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# S_385 (62).tif
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:2731: DecompressionBombWarning: Image size (128403763 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# HBox(children=(IntProgress(value=0, max=66), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=66), HTML(value='')))

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
data_gen_args = dict(rotation_range=20,
                    width_shift_range=0.01,
                    height_shift_range=0.01,
                    shear_range=0.01,
                    zoom_range=0.01,
                    horizontal_flip=True,
                    vertical_flip=True,
                    fill_mode='nearest')

# %%
def trainGenerator(batch_size,train_path,aug_dict=None,target_size = (im_height,im_width),seed = 42):
    '''
    can generate image and mask at the same time
    use the same seed for image_datagen and mask_datagen to ensure the transformation for image and mask is the same
    if you want to visualize the results of generator, set save_to_dir = "your path"
    '''
    if aug_dict: 
        image_datagen = ImageDataGenerator(**aug_dict)
        mask_datagen = ImageDataGenerator(**aug_dict)
    else:
        image_datagen = ImageDataGenerator()
        mask_datagen = ImageDataGenerator()
    image_generator = image_datagen.flow_from_directory(
        train_path + 'images/',
        class_mode = None,
        target_size = target_size,
        batch_size = batch_size,
        seed = seed)
    mask_generator = mask_datagen.flow_from_directory(
        train_path + 'masks/',
        class_mode = None,
        target_size = target_size,
        batch_size = batch_size,
        seed = seed)
    return  (pair for pair in zip(image_generator, mask_generator))

# %%
train_gen = trainGenerator(16, '/tmp/training/patches/')
# Out:
# Found 21975 images belonging to 1 classes.
# Found 21975 images belonging to 1 classes.

# %%
def plot_img(ix):
    x, y = next(train_gen)
    fig, ax = plt.subplots(1, 2, figsize=(20, 10))
    
    ax[0].imshow(((x[0]).astype(np.uint8)))
    ax[0].set_title('Image')

    ax[1].imshow(((y[0]).astype(np.uint8)))
    ax[1].set_title('mask');
    fig.show()

# %%
for i in range(0,5):
    plot_img(np.random.randint(0,21975))

# %%
n_colors = 10

# %%
def preprossesing_image(image, is_image_name=True):
    ''' takes either image filename or file itself and returns a ndarray and width and height
    
    @params: image = filename or image
             is_image_name = True is its a filename or 
                             False if passing image directly'''
    if is_image_name:
        image = Image.open(image)
    if not type(image).__module__ == np.__name__:
        if image.mode in ('RGBA', 'LA'):
            background = Image.new(image.mode[:-1], image.size, (255,255,255))
            background.paste(image, image.split()[-1])
            image = background
        image = np.array(image, dtype=np.float64)/255.
    w, h, d = original_shape = image.shape
    assert d == 3
    image_array = np.reshape(image, (w*h, d))
    return image_array, w, h

# %%
path_train_masks = r'/tmp/training/patches/masks'

# %%
def reshape_label(labels, w, h):
    """ takes 1d array of labels and reshapes it into orignal image height and width
    @params: labels = label
             w = width of image
             h = height of image"""
    
    lbl_reshaped = np.zeros((w, h, 1))
    labels_idx = 0
    for i in range(w):
        for j in range(h):
            lbl_reshaped[i][j] = labels[labels_idx]
            labels_idx += 1
    return lbl_reshaped

# %%
t0 = time()
color_palette_2, w, h = preprossesing_image(r'/content/drive/My Drive/WALL_SEG/color_palette.jpg')
kmeans_color_palette_2 = KMeans(n_clusters=n_colors, random_state=42).fit(color_palette_2)
print('done in %0.3fs. ' % (time() - t0))
print(kmeans_color_palette_2.cluster_centers_)
# Out:
# done in 15.250s.
# [[9.99969192e-01 9.99974928e-01 9.99938496e-01]
#  [9.99935247e-01 4.15438431e-01 7.05848094e-01]
#  [5.01991529e-01 5.01991529e-01 5.01991529e-01]
#  [9.99873380e-01 9.99968000e-01 3.90933333e-03]
#  [1.73866668e-04 1.57992158e-04 9.95901051e-01]
#  [5.01959467e-01 9.42431384e-05 1.74431373e-04]
#  [6.41254916e-05 5.01975718e-01 3.96994510e-03]
#  [9.99936878e-01 3.13098051e-05 1.64645333e-01]
#  [5.05913537e-01 3.13725502e-05 4.98070463e-01]
#  [9.99937380e-01 6.47121129e-01 3.31294119e-05]]

# %%
def display_image_with_labels(labels, w, h, centers):
    ''' convert image back into rgb format from labels
    @params: labels = w x h x 1 ndarray
             centers = cookbook for reference '''
    image = np.zeros((w, h, 3))
    for i, row in enumerate(labels):
        for j, col in enumerate(row):
            image[i][j] = centers[int(col)]
    return image

# %%
def get_labels(image, is_image_name=True):
    ''' converts image into labels using pretrained kmeans algorithm'''
    image_array, w, h = preprossesing_image(image, is_image_name=is_image_name)
    label = reshape_label(kmeans_color_palette_2.predict(image_array), w, h)
    return label, w, h

# %%
img_lbl,w,h = get_labels("/tmp/training/patches/masks/masks/S_385 (26)_0110.jpg")

# %%
print(img_lbl.shape, w , h)
# Out:
# (256, 256, 1) 256 256

# %%
def get_image(label, w = None, h= None, cookbook=kmeans_color_palette_2.cluster_centers_):
    ''' coverts labels back to image'''
    '''if w==None or h==None:
        w, h, _ = label.shape'''
    image = display_image_with_labels(label, w, h, cookbook)
    return image

# %%
plt.imshow(get_image(img_lbl,w,h));

# %%
img_lbl = img_lbl.astype(np.uint8)
one_hot_lbs = tf.one_hot(img_lbl, depth=9, axis=-1)
#one_hot_lbs =  np.squeeze(one_hot_lbs)
one_hot_lbs.shape
# Out:
# TensorShape([256, 256, 1, 9])

# %%
one_hot_2 = np.squeeze(one_hot_lbs)
one_hot_2.shape
# Out:
# (256, 256, 9)

# %%
lbl2 = np.argmax(one_hot_lbs, axis=-1)
lbl2.shape
# Out:
# (256, 256, 1)

# %%
np.array_equal(lbl2, img_lbl)
# Out:
# True

# %%
np.expand_dims(one_hot_2, axis=2).shape
# Out:
# (256, 256, 1, 9)

# %%
lbl3 = np.argmax(np.expand_dims(one_hot_2, axis=2), axis=-1)
lbl3.shape
# Out:
# (256, 256, 1)

# %%
np.array_equal(lbl3, img_lbl)
# Out:
# True

# %%
plt.imshow(get_image(lbl3,w,h));

# %%
colors = np.uint8(kmeans_color_palette_2.cluster_centers_*255)

# %%
colors
# Out:
# array([[254, 254, 254],
#        [254, 105, 179],
#        [128, 128, 128],
#        [254, 254,   0],
#        [  0,   0, 253],
#        [127,   0,   0],
#        [  0, 128,   1],
#        [254,   0,  41],
#        [129,   0, 127],
#        [254, 165,   0]], dtype=uint8)

# %%
indices = np.array([[i for i in range(10)]])
plt.imshow(colors[indices]);

# %%
def conv2d_block(input_tensor, n_filters, kernel_size=3, batchnorm=True):
    # first layer
    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), kernel_initializer="he_normal",
               padding="same")(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation("relu")(x)
    # second layer
    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), kernel_initializer="he_normal",
               padding="same")(x)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

# %%
def get_unet(input_img, n_filters=16, dropout=0.5, batchnorm=True):
    # contracting path
    
    c1 = conv2d_block(input_img, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)
    p1 = MaxPooling2D((2, 2)) (c1)
    p1 = Dropout(dropout*0.5)(p1)

    c2 = conv2d_block(p1, n_filters=n_filters*2, kernel_size=3, batchnorm=batchnorm)
    p2 = MaxPooling2D((2, 2)) (c2)
    p2 = Dropout(dropout)(p2)

    c3 = conv2d_block(p2, n_filters=n_filters*4, kernel_size=3, batchnorm=batchnorm)
    p3 = MaxPooling2D((2, 2)) (c3)
    p3 = Dropout(dropout)(p3)

    c4 = conv2d_block(p3, n_filters=n_filters*8, kernel_size=3, batchnorm=batchnorm)
    p4 = MaxPooling2D(pool_size=(2, 2)) (c4)
    p4 = Dropout(dropout)(p4)
    
    c5 = conv2d_block(p4, n_filters=n_filters*16, kernel_size=3, batchnorm=batchnorm)
    
    # expansive path
    u6 = Conv2DTranspose(n_filters*8, (3, 3), strides=(2, 2), padding='same') (c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters=n_filters*8, kernel_size=3, batchnorm=batchnorm)

    u7 = Conv2DTranspose(n_filters*4, (3, 3), strides=(2, 2), padding='same') (c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters=n_filters*4, kernel_size=3, batchnorm=batchnorm)

    u8 = Conv2DTranspose(n_filters*2, (3, 3), strides=(2, 2), padding='same') (c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters=n_filters*2, kernel_size=3, batchnorm=batchnorm)

    u9 = Conv2DTranspose(n_filters*1, (3, 3), strides=(2, 2), padding='same') (c8)
    u9 = concatenate([u9, c1], axis=3)
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)
    
    outputs = Conv2D(10, (1, 1), activation='softmax') (c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# %%
def dice_coef(y_true, y_pred):
    smooth = 1e-5
    
    y_true = tf.round(tf.reshape(y_true, [-1]))
    y_pred = tf.round(tf.reshape(y_pred, [-1]))
    
    isct = tf.reduce_sum(y_true * y_pred)
    
    return 2 * isct / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred))
def dice_coef_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)

# %%
input_img = Input((im_height, im_width, 3), name='img')
model = get_unet(input_img, n_filters=8, dropout=0.05, batchnorm=False)

model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=[dice_coef, 'acc'])
model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img (InputLayer)                [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 128, 128, 8)  224         img[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 128, 128, 8)  0           conv2d_114[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 128, 128, 8)  584         activation_108[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 128, 128, 8)  0           conv2d_115[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_24 (MaxPooling2D) (None, 64, 64, 8)    0           activation_109[0][0]
# __________________________________________________________________________________________________
# dropout_48 (Dropout)            (None, 64, 64, 8)    0           max_pooling2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 64, 64, 16)   1168        dropout_48[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 64, 64, 16)   0           conv2d_116[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 64, 64, 16)   2320        activation_110[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 64, 64, 16)   0           conv2d_117[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_25 (MaxPooling2D) (None, 32, 32, 16)   0           activation_111[0][0]
# __________________________________________________________________________________________________
# dropout_49 (Dropout)            (None, 32, 32, 16)   0           max_pooling2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 32, 32, 32)   4640        dropout_49[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 32, 32, 32)   0           conv2d_118[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 32, 32, 32)   9248        activation_112[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, 32, 32, 32)   0           conv2d_119[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_26 (MaxPooling2D) (None, 16, 16, 32)   0           activation_113[0][0]
# __________________________________________________________________________________________________
# dropout_50 (Dropout)            (None, 16, 16, 32)   0           max_pooling2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 16, 16, 64)   18496       dropout_50[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 16, 16, 64)   0           conv2d_120[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 16, 16, 64)   36928       activation_114[0][0]
# __________________________________________________________________________________________________
# activation_115 (Activation)     (None, 16, 16, 64)   0           conv2d_121[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_27 (MaxPooling2D) (None, 8, 8, 64)     0           activation_115[0][0]
# __________________________________________________________________________________________________
# dropout_51 (Dropout)            (None, 8, 8, 64)     0           max_pooling2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 8, 8, 128)    73856       dropout_51[0][0]
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, 8, 8, 128)    0           conv2d_122[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 8, 8, 128)    147584      activation_116[0][0]
# __________________________________________________________________________________________________
# activation_117 (Activation)     (None, 8, 8, 128)    0           conv2d_123[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_24 (Conv2DTran (None, 16, 16, 64)   73792       activation_117[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 16, 16, 128)  0           conv2d_transpose_24[0][0]
#                                                                  activation_115[0][0]
# __________________________________________________________________________________________________
# dropout_52 (Dropout)            (None, 16, 16, 128)  0           concatenate_24[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 16, 16, 64)   73792       dropout_52[0][0]
# __________________________________________________________________________________________________
# activation_118 (Activation)     (None, 16, 16, 64)   0           conv2d_124[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 16, 16, 64)   36928       activation_118[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, 16, 16, 64)   0           conv2d_125[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_25 (Conv2DTran (None, 32, 32, 32)   18464       activation_119[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 32, 32, 64)   0           conv2d_transpose_25[0][0]
#                                                                  activation_113[0][0]
# __________________________________________________________________________________________________
# dropout_53 (Dropout)            (None, 32, 32, 64)   0           concatenate_25[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 32, 32, 32)   18464       dropout_53[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 32, 32, 32)   0           conv2d_126[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 32, 32, 32)   9248        activation_120[0][0]
# __________________________________________________________________________________________________
# activation_121 (Activation)     (None, 32, 32, 32)   0           conv2d_127[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_26 (Conv2DTran (None, 64, 64, 16)   4624        activation_121[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 64, 64, 32)   0           conv2d_transpose_26[0][0]
#                                                                  activation_111[0][0]
# __________________________________________________________________________________________________
# dropout_54 (Dropout)            (None, 64, 64, 32)   0           concatenate_26[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 64, 64, 16)   4624        dropout_54[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, 64, 64, 16)   0           conv2d_128[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 64, 64, 16)   2320        activation_122[0][0]
# __________________________________________________________________________________________________
# activation_123 (Activation)     (None, 64, 64, 16)   0           conv2d_129[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_27 (Conv2DTran (None, 128, 128, 8)  1160        activation_123[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 128, 128, 16) 0           conv2d_transpose_27[0][0]
#                                                                  activation_109[0][0]
# __________________________________________________________________________________________________
# dropout_55 (Dropout)            (None, 128, 128, 16) 0           concatenate_27[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 128, 128, 8)  1160        dropout_55[0][0]
# __________________________________________________________________________________________________
# activation_124 (Activation)     (None, 128, 128, 8)  0           conv2d_130[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 128, 128, 8)  584         activation_124[0][0]
# __________________________________________________________________________________________________
# activation_125 (Activation)     (None, 128, 128, 8)  0           conv2d_131[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 128, 128, 10) 90          activation_125[0][0]
# ==================================================================================================
# Total params: 540,298
# Trainable params: 540,298
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import datetime
filename = 'DLmodel_Colab_compact'
logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
callbacks = [
    #EarlyStopping( patience=10, verbose=1),
    ReduceLROnPlateau( factor=0.1, patience=3, min_lr=0.00001, verbose=1),
    ModelCheckpoint(filename + '.h5', verbose=1, save_best_only=True, save_weights_only=True),
    TensorBoard(logdir, histogram_freq=1),
    tf.keras.callbacks.CSVLogger(filename + '_log.csv', append=True, separator=',')
]

# %%
for epoch in range(100):
  for images, masks in train_gen:
    labels = []
    for mask in masks:
        label, w, h = get_labels(mask, is_image_name=False)
        label = label.astype(np.uint8)
        one_hot_mask = tf.one_hot(label, depth=10, axis=-1)
        one_hot_mask = np.squeeze(one_hot_mask)
        labels.append(one_hot_mask)
    labels = np.asarray(labels)
    model.fit(images, labels, verbose=2, callbacks=callbacks, epochs=1, validation_split=0.1)
  print("%0.3f epochs done".format(epoch))
# Out:
# Train on 14 samples, validate on 2 samples
#
# Epoch 00001: val_loss did not improve from 0.00098
# 14/14 - 0s - loss: 0.1204 - dice_coef: 0.9925 - acc: 0.9925 - val_loss: 0.0583 - val_dice_coef: 0.9837 - val_acc: 0.9999
# Train on 14 samples, validate on 2 samples
#
# Epoch 00001: val_loss did not improve from 0.00098
# 14/14 - 0s - loss: 0.0891 - dice_coef: 0.9940 - acc: 0.9955 - val_loss: 0.1279 - val_dice_coef: 0.9921 - val_acc: 0.9921
# Train on 14 samples, validate on 2 samples
#
# Epoch 00001: val_loss did not improve from 0.00098
# 14/14 - 0s - loss: 0.1637 - dice_coef: 0.9898 - acc: 0.9898 - val_loss: 9.8389e-04 - val_dice_coef: 0.9999 - val_acc: 0.9999
# Train on 14 samples, validate on 2 samples
#
# Epoch 00001: val_loss did not improve from 0.00098
# 14/14 - 0s - loss: 0.5807 - dice_coef: 0.9640 - acc: 0.9640 - val_loss: 0.4402 - val_dice_coef: 0.9727 - val_acc: 0.9727
# Train on 14 samples, validate on 2 samples
#
# Epoch 00001: val_loss did not improve from 0.00098
# 14/14 - 0s - loss: 0.0322 - dice_coef: 0.9980 - acc: 0.9980 - val_loss: 0.0708 - val_dice_coef: 0.9956 - val_acc: 0.9956
# Train on 14 samples, validate on 2 samples
#
# Epoch 00001: val_loss did not improve from 0.00098
# 14/14 - 0s - loss: 1.4949 - dice_coef: 0.9073 - acc: 0.9073 - val_loss: 2.4904 - val_dice_coef: 0.8455 - val_acc: 0.8455
# Train on 14 samples, validate on 2 samples
#
# Epoch 00001: val_loss did not improve from 0.00098
# 14/14 - 0s - loss: 1.0936 - dice_coef: 0.9322 - acc: 0.9322 - val_loss: 9.8389e-04 - val_dice_coef: 0.9999 - val_acc: 0.9999
# Train on 14 samples, validate on 2 samples
#
# Epoch 00001: val_loss did not improve from 0.00098
# 14/14 - 0s - loss: 2.1167 - dice_coef: 0.8687 - acc: 0.8687 - val_loss: 9.8389e-04 - val_dice_coef: 0.9999 - val_acc: 0.9999
# Train on 14 samples, validate on 2 samples
#
# Epoch 00001: val_loss did not improve from 0.00098
# 14/14 - 0s - loss: 0.6503 - dice_coef: 0.9590 - acc: 0.9606 - val_loss: 0.0271 - val_dice_coef: 0.9983 - val_acc: 0.9983
# Train on 14 samples, validate on 2 samples
#
# Epoch 00001: val_loss did not improve from 0.00098
# 14/14 - 0s - loss: 2.3739 - dice_coef: 0.8523 - acc: 0.8533 - val_loss: 9.8389e-04 - val_dice_coef: 0.9999 - val_acc: 0.9999
# Train on 14 samples, validate on 2 samples
#
# Epoch 00001: val_loss did not improve from 0.00098
# 14/14 - 0s - loss: 0.0508 - dice_coef: 0.9968 - acc: 0.9969 - val_loss: 9.8389e-04 - val_dice_coef: 0.9999 - val_acc: 0.9999
# Train on 14 samples, validate on 2 samples
#
# Epoch 00001: val_loss did not improve from 0.00098
# 14/14 - 0s - loss: 0.5805 - dice_coef: 0.9579 - acc: 0.9584 - val_loss: 9.8389e-04 - val_dice_coef: 0.9999 - val_acc: 0.9999
# Train on 14 samples, validate on 2 samples
#
# Epoch 00001: val_loss did not improve from 0.00098
# 14/14 - 0s - loss: 0.0376 - dice_coef: 0.9977 - acc: 0.9977 - val_loss: 9.8389e-04 - val_dice_coef: 0.9999 - val_acc: 0.9999
# Train on 14 samples, validate on 2 samples
#
# Epoch 00001: val_loss did not improve from 0.00098
# 14/14 - 0s - loss: 0.9216 - dice_coef: 0.9428 - acc: 0.9429 - val_loss: 0.0182 - val_dice_coef: 0.9989 - val_acc: 0.9989
# Train on 14 samples, validate on 2 samples
#
# Epoch 00001: val_loss did not improve from 0.00098
# 14/14 - 0s - loss: 0.1818 - dice_coef: 0.9884 - acc: 0.9894 - val_loss: 0.5485 - val_dice_coef: 0.9660 - val_acc: 0.9660
# Train on 14 samples, validate on 2 samples
#
# Epoch 00001: val_loss did not improve from 0.00098
# 14/14 - 0s - loss: 0.0267 - dice_coef: 0.9983 - acc: 0.9983 - val_loss: 2.7777 - val_dice_coef: 0.8277 - val_acc: 0.8277
# Train on 14 samples, validate on 2 samples
#
# Epoch 00001: val_loss did not improve from 0.00098
# 14/14 - 0s - loss: 0.0745 - dice_coef: 0.9953 - acc: 0.9955 - val_loss: 2.9085 - val_dice_coef: 0.8195 - val_acc: 0.8195
# Train on 14 samples, validate on 2 samples
#
# Epoch 00001: val_loss did not improve from 0.00098
# 14/14 - 0s - loss: 0.0357 - dice_coef: 0.9973 - acc: 0.9984 - val_loss: 9.8389e-04 - val_dice_coef: 0.9999 - val_acc: 0.9999
# Train on 14 samples, validate on 2 samples
#
# Epoch 00001: val_loss did not improve from 0.00098
# 14/14 - 0s - loss: 0.3261 - dice_coef: 0.9798 - acc: 0.9798 - val_loss: 9.8389e-04 - val_dice_coef: 0.9999 - val_acc: 0.9999
# Train on 14 samples, validate on 2 samples
#
# Epoch 00001: val_loss did not improve from 0.00098
# 14/14 - 0s - loss: 0.5207 - dice_coef: 0.9676 - acc: 0.9682 - val_loss: 0.0059 - val_dice_coef: 0.9996 - val_acc: 0.9996
# Train on 14 samples, validate on 2 samples
#
# Epoch 00001: val_loss did not improve from 0.00098
# 14/14 - 0s - loss: 0.6540 - dice_coef: 0.9594 - acc: 0.9599 - val_loss: 9.8389e-04 - val_dice_coef: 0.9999 - val_acc: 0.9999
# Train on 14 samples, validate on 2 samples
#
# Epoch 00001: val_loss did not improve from 0.00098
# 14/14 - 0s - loss: 3.4664 - dice_coef: 0.7577 - acc: 0.7573 - val_loss: 9.8389e-04 - val_dice_coef: 0.9999 - val_acc: 0.9999
# Train on 14 samples, validate on 2 samples
#
# Epoch 00001: val_loss did not improve from 0.00098
# 14/14 - 0s - loss: 0.2635 - dice_coef: 0.9833 - acc: 0.9839 - val_loss: 9.8389e-04 - val_dice_coef: 0.9999 - val_acc: 0.9999
# Train on 14 samples, validate on 2 samples
#
# Epoch 00001: val_loss did not improve from 0.00098
# 14/14 - 0s - loss: 0.0131 - dice_coef: 0.9992 - acc: 0.9992 - val_loss: 9.8389e-04 - val_dice_coef: 0.9999 - val_acc: 0.9999
# Train on 14 samples, validate on 2 samples
#
# Epoch 00001: val_loss did not improve from 0.00098
# 14/14 - 0s - loss: 0.9359 - dice_coef: 0.9415 - acc: 0.9425 - val_loss: 9.8389e-04 - val_dice_coef: 0.9999 - val_acc: 0.9999
# Train on 14 samples, validate on 2 samples
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-115-c9444cc76285> in <module>()
#       9         labels.append(one_hot_mask)
#      10     labels = np.asarray(labels)
# ---> 11     model.fit(images, labels, verbose=2, callbacks=callbacks, epochs=1, validation_split=0.1)
#      12   print("%0.3f epochs done".format(epoch))
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/engine/training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     305           count_mode='samples' if use_sample else 'steps',
#     306           verbose=0,  # Handle ProgBarLogger separately in this loop.
# --> 307           mode=ModeKeys.TRAIN)
#     308
#     309       with training_context.on_start(model, training_callbacks, use_sample,
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/callbacks.py in configure_callbacks(callbacks, model, do_validation, batch_size, epochs, steps_per_epoch, samples, verbose, count_mode, mode)
#     105   # Set callback model
#     106   callback_model = model._get_callback_model()  # pylint: disable=protected-access
# --> 107   callback_list.set_model(callback_model)
#     108
#     109   set_callback_parameters(
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/callbacks.py in set_model(self, model)
#     220     self.model = model
#     221     for callback in self.callbacks:
# --> 222       callback.set_model(model)
#     223
#     224   def _call_batch_hook(self, mode, hook, batch, logs=None):
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/callbacks.py in set_model(self, model)
#    1538           with summary_ops_v2.always_record_summaries():
#    1539             if not model.run_eagerly:
# -> 1540               summary_ops_v2.graph(K.get_graph(), step=0)
#    1541
#    1542             summary_writable = (
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/ops/summary_ops_v2.py in graph(param, step, name)
#     898   with ops.device("cpu:0"):
#     899     if isinstance(param, (ops.Graph, graph_pb2.GraphDef)):
# --> 900       tensor = ops.convert_to_tensor(_serialize_graph(param), dtypes.string)
#     901     else:
#     902       tensor = array_ops.identity(param)
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/ops/summary_ops_v2.py in _serialize_graph(arbitrary_graph)
#     974 def _serialize_graph(arbitrary_graph):
#     975   if isinstance(arbitrary_graph, ops.Graph):
# --> 976     return arbitrary_graph.as_graph_def(add_shapes=True).SerializeToString()
#     977   else:
#     978     return arbitrary_graph.SerializeToString()
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/framework/ops.py in as_graph_def(self, from_version, add_shapes)
#    3132     """
#    3133     # pylint: enable=line-too-long
# -> 3134     result, _ = self._as_graph_def(from_version, add_shapes)
#    3135     return result
#    3136
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/framework/ops.py in _as_graph_def(self, from_version, add_shapes)
#    3049         data = c_api.TF_GetBuffer(buf)
#    3050       graph = graph_pb2.GraphDef()
# -> 3051       graph.ParseFromString(compat.as_bytes(data))
#    3052       # Strip the experimental library field iff it's empty.
#    3053       if not graph.library.function:
#
# KeyboardInterrupt:

# %%
for images, masks in train_gen:
  y_pred = model.predict(images)
  test_labels = []
  for mask in masks:
      label, w, h = get_labels(mask, is_image_name=False)
      label = label.astype(np.uint8)
      one_hot_mask = tf.one_hot(label, depth=10, axis=-1)
      one_hot_mask = np.squeeze(one_hot_mask)
      test_labels.append(one_hot_mask)
  test_labels = np.asarray(labels)
  print(dice_coef(test_labels, y_pred))
  y_pred_int = np.expand_dims(y_pred, axis=3)
  y_pred_lbl = np.argmax(y_pred_int, axis=-1)
  plt.imshow(get_image(y_pred_lbl[np.random.randint(0,16)],w,h))
  plt.show()
# Out:
# tf.Tensor(0.97377825, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.9726656, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.97416866, shape=(), dtype=float32)
# tf.Tensor(0.97383696, shape=(), dtype=float32)
# tf.Tensor(0.97293365, shape=(), dtype=float32)
# tf.Tensor(0.9730714, shape=(), dtype=float32)
# tf.Tensor(0.97289246, shape=(), dtype=float32)
# tf.Tensor(0.9728491, shape=(), dtype=float32)
# tf.Tensor(0.9729026, shape=(), dtype=float32)
# tf.Tensor(0.9725548, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.97306895, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.97280204, shape=(), dtype=float32)
# tf.Tensor(0.9738755, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.9721839, shape=(), dtype=float32)
# tf.Tensor(0.97289866, shape=(), dtype=float32)
# tf.Tensor(0.97344726, shape=(), dtype=float32)
# tf.Tensor(0.9728869, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.97170895, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.97275156, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.97344726, shape=(), dtype=float32)
# tf.Tensor(0.9735551, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.972297, shape=(), dtype=float32)
# tf.Tensor(0.9724685, shape=(), dtype=float32)
# tf.Tensor(0.97400385, shape=(), dtype=float32)
# tf.Tensor(0.97299063, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.9726221, shape=(), dtype=float32)
# tf.Tensor(0.97179335, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.9736157, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.9727397, shape=(), dtype=float32)
# tf.Tensor(0.9731885, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.9718171, shape=(), dtype=float32)
# tf.Tensor(0.97344726, shape=(), dtype=float32)
# tf.Tensor(0.97302186, shape=(), dtype=float32)
# tf.Tensor(0.9741645, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.9716656, shape=(), dtype=float32)
# tf.Tensor(0.9741193, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.9730711, shape=(), dtype=float32)
# tf.Tensor(0.97398376, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.97234344, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.97415906, shape=(), dtype=float32)
# tf.Tensor(0.9735971, shape=(), dtype=float32)
# tf.Tensor(0.97343343, shape=(), dtype=float32)
# tf.Tensor(0.9729555, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.97397995, shape=(), dtype=float32)
# tf.Tensor(0.9732208, shape=(), dtype=float32)
# tf.Tensor(0.97286224, shape=(), dtype=float32)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-112-510f4ccca4db> in <module>()
#      13   y_pred_lbl = np.argmax(y_pred_int, axis=-1)
#      14   plt.imshow(get_image(y_pred_lbl[np.random.randint(0,16)],w,h))
# ---> 15   plt.show()
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in show(*args, **kw)
#     267     """
#     268     global _show
# --> 269     return _show(*args, **kw)
#     270
#     271
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      34     try:
#      35         for figure_manager in Gcf.get_all_fig_managers():
# ---> 36             display(figure_manager.canvas.figure)
#      37     finally:
#      38         show._to_draw = []
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/display.py in display(*objs, **kwargs)
#     304             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     305         else:
# --> 306             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     307             if not format_dict:
#     308                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     171             md = None
#     172             try:
# --> 173                 data = formatter(obj)
#     174             except:
#     175                 # FIXME: log the exception
#
# </usr/local/lib/python3.6/dist-packages/decorator.py:decorator-gen-9> in __call__(self, obj)
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     215     """show traceback on failed format call"""
#     216     try:
# --> 217         r = method(self, *args, **kwargs)
#     218     except NotImplementedError:
#     219         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     332                 pass
#     333             else:
# --> 334                 return printer(obj)
#     335             # Finally look for special method names
#     336             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     239
#     240     if 'png' in formats:
# --> 241         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     242     if 'retina' in formats or 'png2x' in formats:
#     243         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     123
#     124     bytes_io = BytesIO()
# --> 125     fig.canvas.print_figure(bytes_io, **kw)
#     126     data = bytes_io.getvalue()
#     127     if fmt == 'svg':
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2067                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#    2068                     bbox_inches = self.figure.get_tightbbox(renderer,
# -> 2069                             bbox_extra_artists=bbox_artists)
#    2070                     pad = kwargs.pop("pad_inches", None)
#    2071                     if pad is None:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    2365
#    2366         for a in artists:
# -> 2367             bbox = a.get_tightbbox(renderer)
#    2368             if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    2369                 bb.append(bbox)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/artist.py in get_tightbbox(self, renderer)
#     282             The enclosing bounding box (in figure pixel co-ordinates).
#     283         """
# --> 284         bbox = self.get_window_extent(renderer)
#     285         if self.get_clip_on():
#     286             clip_box = self.get_clip_box()
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     878             self.figure.dpi = dpi
#     879         if self.get_text() == '':
# --> 880             tx, ty = self._get_xy_display()
#     881             return Bbox.from_bounds(tx, ty, 0, 0)
#     882
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/text.py in _get_xy_display(self)
#     221         Get the (possibly unit converted) transformed x, y in display coords.
#     222         """
# --> 223         x, y = self.get_unitless_position()
#     224         return self.get_transform().transform_point((x, y))
#     225
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/text.py in get_unitless_position(self)
#     811         # This will get the position with all unit information stripped away.
#     812         # This is here for convenience since it is done in several locations.
# --> 813         x = float(self.convert_xunits(self._x))
#     814         y = float(self.convert_yunits(self._y))
#     815         return x, y
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/artist.py in convert_xunits(self, x)
#     178         if ax is None or ax.xaxis is None:
#     179             return x
# --> 180         return ax.xaxis.convert_units(x)
#     181
#     182     def convert_yunits(self, y):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axis.py in convert_units(self, x)
#    1539     def convert_units(self, x):
#    1540         # If x is already a number, doesn't need converting
# -> 1541         if munits.ConversionInterface.is_numlike(x):
#    1542             return x
#    1543
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/units.py in is_numlike(x)
#     134                 return isinstance(thisx, Number)
#     135         else:
# --> 136             return isinstance(x, Number)
#     137
#     138
#
# /usr/lib/python3.6/abc.py in __instancecheck__(cls, instance)
#     178                 print("%s: %r" % (name, value), file=file)
#     179
# --> 180     def __instancecheck__(cls, instance):
#     181         """Override for isinstance(instance, cls)."""
#     182         # Inline the cache checking
#
# KeyboardInterrupt:

# %%
np.expand_dims(one_hot_2, axis=2).shape
# Out:
# (256, 256, 1, 9)

# %%
lbl3 = np.argmax(np.expand_dims(one_hot_2, axis=2), axis=-1)
lbl3.shape
# Out:
# (256, 256, 1)

# %%
def create_mask_set(train_gen = train_gen):
    for images, masks in train_gen:
        new_lables = []
        for mask in masks:
            label, w, h = get_labels(mask, is_image_name=False)
            new_lables.append(label)
        yield(images, np.asarray(new_lables))

# %%
lab_gen = create_mask_set()
def plot_img2(ix):
    x, y = next(lab_gen)
    fig, ax = plt.subplots(1, 2, figsize=(20, 10))
    
    ax[0].imshow(((x[0]).astype(np.uint8)))
    ax[0].set_title('Image')

    ax[1].imshow((get_image(y[0], w = y[0].shape[0], h = y[0].shape[1])))
    ax[1].set_title('mask');
    fig.show()

# %%
for i in range(0,10):
    plot_img2(np.random.randint(0,16))

# %%
lab_gen = create_mask_set()
new_images, new_labels = next(lab_gen)
plt.imshow(get_image(new_labels[0], w=new_labels[0].shape[0], h=new_labels[0].shape[1]))
plt.show()

# %%
fresh_big_img_loc = r'/content/drive/My Drive/WALL_SEG/Masks/S_385 (20).png'
plt.imshow(Image.open(fresh_big_img_loc))

# %%
fresh_big_img_loc_label, w_, h_ = get_labels(fresh_big_img_loc)
fresh_big_img_loc_image = get_image(fresh_big_img_loc_label, w = w_, h = h_)

# %%
fresh_big_img_loc_label.shape, fresh_big_img_loc_image.shape
# Out:
# ((7808, 8831, 1), (7808, 8831, 3))

# %%
plt.imshow(fresh_big_img_loc_image)

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot( np.argmin(results.history["val_loss"]), 
         np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();

# %%
# Load best model
model.load_weights('model-unet-basic_tf2.h5')

# %%
model.evaluate(X_valid, y_valid, verbose=1)

# %%
# Predict on train, val and test
preds_train = model.predict(X_train, verbose=1)
preds_val = model.predict(X_valid, verbose=1)

# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)

# %%
def plot_sample(X, y, preds, binary_preds, ix=None):
    if ix is None:
        ix = random.randint(0, len(X))

    has_mask = y[ix].max() > 0

    fig, ax = plt.subplots(1, 3, figsize=(20, 10))
    ax[0].imshow(X[ix])
   
    ax[0].set_title('Image')

    ax[1].imshow(y[ix].squeeze())
    ax[1].set_title('Mask')

    ax[2].imshow(preds[ix].squeeze(), vmin=0, vmax=1)
   
    ax[2].set_title('Mask Predicted')

# %%
# Check if training data looks all right
for i in range(0,10):
    plot_sample(X_train, y_train, preds_train, preds_train_t)

# %%
# Check if valid data looks all right
plot_sample(X_valid, y_valid, preds_val, preds_val_t)

# %%
path_test = os.path.join( os.getcwd(), 'input',  'test')
X_test, y_test = get_data(path_test, train=True)

# %%
preds_test = model.predict(X_test, verbose=1)

# %%
preds_test_t = (preds_test > 0.5).astype(np.uint8)

# %%
plot_sample(X_test, y_test, preds_test, preds_test_t, ix=15)

# %%
path_big = os.path.join(os.getcwd(), 'input', 'big')
X_big, y_big = get_data(path_big, train=True)

# %%
preds_big = model.predict(X_big, verbose=1)

# %%
preds_big_t = (preds_big > 0.5).astype(np.uint8)
plot_sample(X_big, y_big, preds_big, preds_big_t, ix=0)

# %%
plt.imshow(X_big[0])

# %%
for i in range(10):
    plot_sample(X_test, y_test, preds_test, preds_test_t, ix=i)

# %%
# %tensorboard --logdir log\s
# Out:
# ERROR: Timed out waiting for TensorBoard to start. It may still be running as pid 7832.
