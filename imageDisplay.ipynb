# %%
import matplotlib.pyplot as plt
from skimage.io import imread
import os

# %%
path_mask = 'D:\wall_segmentation\Images\masks_S385\S_385 (23).png'
path_image = 'D:\wall_segmentation\Images\S_385\S_385 (23).tif'

# %%
image = imread(path_image)
mask = imread(path_mask)

# %%
plt.imshow(image)

# %%
plt.imshow(mask)

# %%
plt.figure(figsize= (20,20))

plt.imshow(image)
plt.imshow(mask, alpha=.5)
plt.show()
