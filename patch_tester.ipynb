# %%
import patches
import os

# %%
path = os.path.join(os.getcwd(), 'model_basic', 'input', 'train', 'images')
path
# Out:
# 'D:\\GitHub\\DLforWallCharacteristics\\model_basic\\input\\train\\images'

# %%
image_1 = next(os.walk(path))[2][1]
image_2 = next(os.walk(path))[2][2]

# %%
from skimage.io import imread

# %%
image1 = imread(os.path.join(path, image_1))
image2 = imread(os.path.join(path, image_2))

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(image1)

# %%
plt.imshow(image2)

# %%
image_patches1 = patches.extract_patches(image1, (256,265), overlap_allowed=0)

# %%
image_patches2 = patches.extract_patches(image1, (256,265))

# %%
patches.plot_patches(image_patches)

# %%
image_patches1.shape
# Out:
# (2409, 256, 265, 3)

# %%
image_patches2.shape
# Out:
# (9570, 256, 265, 3)

# %%
plt.imshow(image_patches2[513])

# %%
image.shape
