# %%
import patches
import os

# %%
path = os.path.join(os.getcwd(), 'model_basic', 'input', 'train', 'images')
path
# Out:
# 'D:\\GitHub\\DLforWallCharacteristics\\model_basic\\input\\train\\images'

# %%
image_id = next(os.walk(path))[2][2]

# %%
from skimage.io import imread

# %%
image = imread(os.path.join(path, image_id))

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(image)

# %%
image_patches = patches.extract_patches(image, (256,265))

# %%
patches.plot_patches(image_patches)

# %%
image_patches.shape
# Out:
# (2832, 256, 265, 3)

# %%
plt.imshow(image_patches[2831])

# %%
image.shape
